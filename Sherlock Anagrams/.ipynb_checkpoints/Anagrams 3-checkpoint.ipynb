# %% [markdown]
# #

# %%
#!/bin/python3

import math
import os
import random
import re
import sys


name_test = 'temp'
os.environ['OUTPUT_PATH'] = f"./out/{name_test}.txt"

# %%
from itertools import combinations
from math import comb
from collections import defaultdict

# %%
from copy import deepcopy

# %%
temp_str = 'dsadas'
temp_str[1:3]
# Out:
# 'sa'

# %%
def sherlockAndAnagrams(s):
    global list_dict
    global dict_all
    global list_dict_possible
    
    total = 0
    
    list_dict = []
    dict_1 = defaultdict(set)
    
    list_dict.append(dict_1)

    for i, char in enumerate(s):
        dict_1[char].add(i)
            
    dict_1 = {k:v for k,v in dict_1.items() if len(v) >= 1}
    
    i_d = 0

#     print(dict_1)
#     print(list_dict[i_d])
    
    while len(list_dict[i_d]) > 0:
#         print(f'--------- In substring length = {i_d+1}')
#         print(list_dict[i_d])
        
#         print(f'Length of cur_dict i=[{i_d}] | [{len(list_dict[i_d])}] ')
        cur_dict = list_dict[i_d]
        
        next_dict = defaultdict(set)
        i_d += 1
        
        for k,v in cur_dict.items():
            
            for i in v:
                if i-1 >= 0:
                    next_dict["".join(sorted(s[i-1:i+i_d]))].add(i-1)
                    
                if i_d + i < len(s):
                    next_dict["".join(sorted(s[i:i+i_d+1]))].add(i)
                    
        next_dict = {k:v for k,v in next_dict.items() if len(v) >= 2}
        
        if next_dict:
            list_dict.append(next_dict)

        else:
#             print(next_dict)
            break

    
#     print('------ Initial dict_all ------')  
#     print(dict_all)
    
    
# ------------------ Part 3


    list_dict_possible = deepcopy(list_dict)
    
    all_i = set.union(*dict_1.values())
    
    for i in range(1,len(s)):
        
        next_dict_possible = defaultdict(set)
        
        if len(list_dict_possible) > i:
            next_dict_possible.update(list_dict_possible[i])
            
        else:
            print(f'No previous dict for i = [{i}] | cur_len = [{len(list_dict_possible)}]')
        
        cur_dict = list_dict_possible[i-1]
        if not cur_dict:
            break
        
        print('Before Inner Loop')
        
        print(' --- next_dict_possible ---')
        print(next_dict_possible)
        print(' --- cur_dict ---')
        print(cur_dict)
        
        
        #for k, v in cur_dict.items():
        
        list_v = set.union(*cur_dict.values())
        
        pairs = combinations(list_v, 2)
        
        if i == 1:
            pairs = [(l,r) for l, r in pairs if s[l] == s[r]]

        for pair in pairs:

            pair = sorted(pair)
            len_k = i

            possible_pairs = get_adjacent(pair[0],pair[1],len_k,all_i)

            cur_str_l = "".join(sorted(s[pair[0]:pair[0]+len_k]))
            cur_str_r = "".join(sorted(s[pair[1]:pair[1]+len_k]))                 

            print(f'Possible pairs for [{cur_str_l}] [{cur_str_r}]')

            for pos_pair in possible_pairs:
                l_pos, r_pos = pos_pair
                l_sub = "".join(sorted(s[l_pos:l_pos+len_k+1]))
                r_sub = "".join(sorted(s[r_pos:r_pos+len_k+1]))

                next_dict_possible[l_sub].add(l_pos)
                next_dict_possible[r_sub].add(r_pos)

                print(f'Pair: [{l_sub}] [{r_sub}] ->  [{l_pos}] [{r_pos}] ')
                    
                
             
        next_dict = {k:v for k,v in next_dict_possible.items() if len(v) >= 2}
        
        if len(list_dict) > i:
            list_dict_possible[i].update(next_dict_possible)
            list_dict[i] = next_dict
            
            print(f'-------------- In len(list_dict) > {i} ---------------- ')
        
        else:
            print(f'-------------- In len(list_dict) <= {i} ---------------- ')
            
            list_dict_possible.append(next_dict_possible)
            list_dict.append(next_dict)
            
        print('After Inner Loop')
        print(next_dict_possible)
    
    
    # Check for equality -> Insert to dict_all
    
    dict_all = defaultdict(set)
    dict_all.update({key:val for d in list_dict for key,val in d.items()})
    
        
    for k in list(dict_all):
        v_pairs = combinations(dict_all[k], 2)
        for pair in v_pairs:
            
            pair = sorted(pair)
            
            len_k = len(k)
            
            dict_all["".join(sorted(s[pair[0]:pair[1]]))].add(pair[0])
            dict_all["".join(sorted(s[pair[0]+len_k:pair[1]+len_k]))].add(pair[0]+len_k)
   
    for set_s in dict_all.values():
        total += comb(len(set_s), 2)
    
    print(f'Answer = [{total}]')
    
    return total

# %%
def get_adjacent(i, j, len_k, all_i):
    
#     is_adj_left = i-1 in all_i or i+k in all_i
#     is_adj_right = j-1 in all_i or j+k in all_i

    l_pair = []
    r_pair = []
    
    if i-1 in all_i:
        l_pair.append(i-1)
    if i+len_k in all_i:
          l_pair.append(i)
#         l_pair.append(i+len_k)
    
    if j-1 in all_i:
        r_pair.append(j-1)
        
    if j+len_k in all_i:
        r_pair.append(j)
#         r_pair.append(j+len_k)
    
    
    return product(l_pair, r_pair)

# %%
#old_list_dict = list_dict

# %%
len(new_list_dict)
# Out:
# 100

# %%
new_list_dict[0]
# Out:
# defaultdict(set,
#             {'d': {0, 40, 50, 59, 67, 73, 98},
#              'b': {1, 5, 7, 61, 69, 72, 81},
#              'c': {2,
#               8,
#               14,
#               15,
#               17,
#               22,
#               25,
#               35,
#               44,
#               64,
#               65,
#               71,
#               74,
#               86,
#               88,
#               93,
#               97},
#              'f': {3, 13, 18, 27, 48, 53, 54, 57, 60, 79, 80, 84, 85, 92, 95},
#              'i': {4, 6, 11, 21, 23, 28, 43, 51, 56, 58, 76, 82},
#              'h': {9, 37, 41, 45, 49, 90, 96},
#              'e': {10, 19, 26, 29, 30, 31, 32, 33, 42, 62, 70, 77, 87},
#              'g': {12, 20, 24, 34, 36, 38, 39, 46, 52, 55, 75, 83, 99},
#              'a': {16, 47, 63, 66, 68, 78, 89, 91, 94}})

# %%
new_list_dict[14]
# Out:
# {'abe': {61, 68},
#  'bce': {69, 70},
#  'cdg': {73, 97},
#  'bcd': {71, 72},
#  'egi': {19, 75},
#  'cgi': {20, 22, 23, 74},
#  'cef': {17, 25},
#  'efi': {26, 27},
#  'acc': {14, 15, 63, 64},
#  'acf': {16, 91, 92, 93},
#  'ceg': {24, 33},
#  'eee': {29, 30},
#  'afh': {90, 94},
#  'bd': {0, 72},
#  'bi': {4, 5, 6, 81},
#  'eh': {9, 41},
#  'fi': {3, 27, 56, 57},
#  'ce': {25, 70, 86, 87},
#  'cd': {73, 97},
#  'gi': {11, 20, 23, 51, 55, 75, 82},
#  'cf': {2, 13, 17, 85, 92},
#  'cc': {14, 64},
#  'ff': {53, 79, 84},
#  'fg': {12, 52, 54, 83},
#  'ad': {66, 67},
#  'ac': {15, 16, 63, 65, 88, 93},
#  'ef': {18, 26},
#  'ah': {89, 90},
#  'fh': {48, 95},
#  'ae': {62, 77},
#  'bf': {60, 80},
#  'bc': {1, 7, 71},
#  'ch': {8, 44, 96},
#  'ee': {29, 30, 31, 32},
#  'cg': {24, 34, 35, 74},
#  'ci': {21, 22, 43},
#  'af': {47, 78, 91, 94},
#  'be': {61, 69},
#  'dh': {40, 49},
#  'di': {50, 58},
#  'g': {12, 20, 24, 34, 36, 38, 39, 46, 52, 55, 75, 83, 99},
#  'ei': {10, 28, 42, 76},
#  'eg': {19, 33},
#  'gh': {36, 37, 45},
#  'dg': {39, 98},
#  'e': {10, 19, 26, 29, 30, 31, 32, 33, 42, 62, 70, 77, 87},
#  'b': {1, 5, 7, 61, 69, 72, 81},
#  'c': {2, 8, 14, 15, 17, 22, 25, 35, 44, 64, 65, 71, 74, 86, 88, 93, 97},
#  'h': {9, 37, 41, 45, 49, 90, 96},
#  'i': {4, 6, 11, 21, 23, 28, 43, 51, 56, 58, 76, 82},
#  'a': {16, 47, 63, 66, 68, 78, 89, 91, 94},
#  'f': {3, 13, 18, 27, 48, 53, 54, 57, 60, 79, 80, 84, 85, 92, 95},
#  'd': {0, 40, 50, 59, 67, 73, 98},
#  'dfi': {57, 58},
#  'ffg': {52, 53},
#  'fgi': {51, 54, 55}}

# %%
dict_a

# %%
old_list_dict[7]
# Out:
# {'acccefgi': {10, 14, 15}, 'ccefggii': {17, 18, 20}}

# %%
dict_all['ceghi']
# Out:
# set()

# %%
new_dict_all['ceg']
# Out:
# {24, 33}

# %%
old_dict_all['ceg']
# Out:
# {24, 33}

# %%
dict_possible_all = defaultdict(set)
dict_possible_all.update({key:val for d in list_dict_possible for key,val in d.items()})

# %%
dict_possible_all['ceg']
# Out:
# {24, 33}

# %% [markdown]
# ### Run

# %%
input_str = 'xabcd1234cadby'
# input_str = 'dbcfibibcheigfccacfegicigcefieeeeegcghggdheichgafhdigffgifidfbeaccadabecbdcgieaffbigffcecahafcafhcdg'

# %%
sherlockAndAnagrams(input_str)
# Out:
# No previous dict for i = [1] | cur_len = [1]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'x': {0}, 'a': {1, 10}, 'b': {2, 12}, 'c': {9, 3}, 'd': {11, 4}, '1': {5}, '2': {6}, '3': {7}, '4': {8}, 'y': {13}})
# Possible pairs for [a] [a]
# Pair: [ax] [ac] ->  [0] [9]
# Pair: [ax] [ad] ->  [0] [10]
# Pair: [ab] [ac] ->  [1] [9]
# Pair: [ab] [ad] ->  [1] [10]
# Possible pairs for [b] [b]
# Pair: [ab] [bd] ->  [1] [11]
# Pair: [ab] [by] ->  [1] [12]
# Pair: [bc] [bd] ->  [2] [11]
# Pair: [bc] [by] ->  [2] [12]
# Possible pairs for [c] [c]
# Pair: [bc] [4c] ->  [2] [8]
# Pair: [bc] [ac] ->  [2] [9]
# Pair: [cd] [4c] ->  [3] [8]
# Pair: [cd] [ac] ->  [3] [9]
# Possible pairs for [d] [d]
# Pair: [cd] [ad] ->  [3] [10]
# Pair: [cd] [bd] ->  [3] [11]
# Pair: [1d] [ad] ->  [4] [10]
# Pair: [1d] [bd] ->  [4] [11]
# -------------- In len(list_dict) <= 1 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'ax': {0}, 'ac': {9}, 'ad': {10}, 'ab': {1}, 'bd': {11}, 'by': {12}, 'bc': {2}, '4c': {8}, 'cd': {3}, '1d': {4}})
# No previous dict for i = [2] | cur_len = [2]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'ax': {0}, 'ac': {9}, 'ad': {10}, 'ab': {1}, 'bd': {11}, 'by': {12}, 'bc': {2}, '4c': {8}, 'cd': {3}, '1d': {4}})
# Possible pairs for [ax] [ab]
# Pair: [abx] [abx] ->  [0] [0]
# Pair: [abx] [abc] ->  [0] [1]
# Possible pairs for [ax] [bc]
# Pair: [abx] [abc] ->  [0] [1]
# Pair: [abx] [bcd] ->  [0] [2]
# Possible pairs for [ax] [cd]
# Pair: [abx] [bcd] ->  [0] [2]
# Pair: [abx] [1cd] ->  [0] [3]
# Possible pairs for [ax] [1d]
# Pair: [abx] [1cd] ->  [0] [3]
# Pair: [abx] [12d] ->  [0] [4]
# Possible pairs for [ax] [4c]
# Pair: [abx] [34c] ->  [0] [7]
# Pair: [abx] [4ac] ->  [0] [8]
# Possible pairs for [ax] [ac]
# Pair: [abx] [4ac] ->  [0] [8]
# Pair: [abx] [acd] ->  [0] [9]
# Possible pairs for [ax] [ad]
# Pair: [abx] [acd] ->  [0] [9]
# Pair: [abx] [abd] ->  [0] [10]
# Possible pairs for [ax] [bd]
# Pair: [abx] [abd] ->  [0] [10]
# Pair: [abx] [bdy] ->  [0] [11]
# Possible pairs for [ax] [by]
# Pair: [abx] [bdy] ->  [0] [11]
# Possible pairs for [ab] [bc]
# Pair: [abx] [abc] ->  [0] [1]
# Pair: [abx] [bcd] ->  [0] [2]
# Pair: [abc] [abc] ->  [1] [1]
# Pair: [abc] [bcd] ->  [1] [2]
# Possible pairs for [ab] [cd]
# Pair: [abx] [bcd] ->  [0] [2]
# Pair: [abx] [1cd] ->  [0] [3]
# Pair: [abc] [bcd] ->  [1] [2]
# Pair: [abc] [1cd] ->  [1] [3]
# Possible pairs for [ab] [1d]
# Pair: [abx] [1cd] ->  [0] [3]
# Pair: [abx] [12d] ->  [0] [4]
# Pair: [abc] [1cd] ->  [1] [3]
# Pair: [abc] [12d] ->  [1] [4]
# Possible pairs for [ab] [4c]
# Pair: [abx] [34c] ->  [0] [7]
# Pair: [abx] [4ac] ->  [0] [8]
# Pair: [abc] [34c] ->  [1] [7]
# Pair: [abc] [4ac] ->  [1] [8]
# Possible pairs for [ab] [ac]
# Pair: [abx] [4ac] ->  [0] [8]
# Pair: [abx] [acd] ->  [0] [9]
# Pair: [abc] [4ac] ->  [1] [8]
# Pair: [abc] [acd] ->  [1] [9]
# Possible pairs for [ab] [ad]
# Pair: [abx] [acd] ->  [0] [9]
# Pair: [abx] [abd] ->  [0] [10]
# Pair: [abc] [acd] ->  [1] [9]
# Pair: [abc] [abd] ->  [1] [10]
# Possible pairs for [ab] [bd]
# Pair: [abx] [abd] ->  [0] [10]
# Pair: [abx] [bdy] ->  [0] [11]
# Pair: [abc] [abd] ->  [1] [10]
# Pair: [abc] [bdy] ->  [1] [11]
# Possible pairs for [ab] [by]
# Pair: [abx] [bdy] ->  [0] [11]
# Pair: [abc] [bdy] ->  [1] [11]
# Possible pairs for [bc] [cd]
# Pair: [abc] [bcd] ->  [1] [2]
# Pair: [abc] [1cd] ->  [1] [3]
# Pair: [bcd] [bcd] ->  [2] [2]
# Pair: [bcd] [1cd] ->  [2] [3]
# Possible pairs for [bc] [1d]
# Pair: [abc] [1cd] ->  [1] [3]
# Pair: [abc] [12d] ->  [1] [4]
# Pair: [bcd] [1cd] ->  [2] [3]
# Pair: [bcd] [12d] ->  [2] [4]
# Possible pairs for [bc] [4c]
# Pair: [abc] [34c] ->  [1] [7]
# Pair: [abc] [4ac] ->  [1] [8]
# Pair: [bcd] [34c] ->  [2] [7]
# Pair: [bcd] [4ac] ->  [2] [8]
# Possible pairs for [bc] [ac]
# Pair: [abc] [4ac] ->  [1] [8]
# Pair: [abc] [acd] ->  [1] [9]
# Pair: [bcd] [4ac] ->  [2] [8]
# Pair: [bcd] [acd] ->  [2] [9]
# Possible pairs for [bc] [ad]
# Pair: [abc] [acd] ->  [1] [9]
# Pair: [abc] [abd] ->  [1] [10]
# Pair: [bcd] [acd] ->  [2] [9]
# Pair: [bcd] [abd] ->  [2] [10]
# Possible pairs for [bc] [bd]
# Pair: [abc] [abd] ->  [1] [10]
# Pair: [abc] [bdy] ->  [1] [11]
# Pair: [bcd] [abd] ->  [2] [10]
# Pair: [bcd] [bdy] ->  [2] [11]
# Possible pairs for [bc] [by]
# Pair: [abc] [bdy] ->  [1] [11]
# Pair: [bcd] [bdy] ->  [2] [11]
# Possible pairs for [cd] [1d]
# Pair: [bcd] [1cd] ->  [2] [3]
# Pair: [bcd] [12d] ->  [2] [4]
# Pair: [1cd] [1cd] ->  [3] [3]
# Pair: [1cd] [12d] ->  [3] [4]
# Possible pairs for [cd] [4c]
# Pair: [bcd] [34c] ->  [2] [7]
# Pair: [bcd] [4ac] ->  [2] [8]
# Pair: [1cd] [34c] ->  [3] [7]
# Pair: [1cd] [4ac] ->  [3] [8]
# Possible pairs for [cd] [ac]
# Pair: [bcd] [4ac] ->  [2] [8]
# Pair: [bcd] [acd] ->  [2] [9]
# Pair: [1cd] [4ac] ->  [3] [8]
# Pair: [1cd] [acd] ->  [3] [9]
# Possible pairs for [cd] [ad]
# Pair: [bcd] [acd] ->  [2] [9]
# Pair: [bcd] [abd] ->  [2] [10]
# Pair: [1cd] [acd] ->  [3] [9]
# Pair: [1cd] [abd] ->  [3] [10]
# Possible pairs for [cd] [bd]
# Pair: [bcd] [abd] ->  [2] [10]
# Pair: [bcd] [bdy] ->  [2] [11]
# Pair: [1cd] [abd] ->  [3] [10]
# Pair: [1cd] [bdy] ->  [3] [11]
# Possible pairs for [cd] [by]
# Pair: [bcd] [bdy] ->  [2] [11]
# Pair: [1cd] [bdy] ->  [3] [11]
# Possible pairs for [1d] [4c]
# Pair: [1cd] [34c] ->  [3] [7]
# Pair: [1cd] [4ac] ->  [3] [8]
# Pair: [12d] [34c] ->  [4] [7]
# Pair: [12d] [4ac] ->  [4] [8]
# Possible pairs for [1d] [ac]
# Pair: [1cd] [4ac] ->  [3] [8]
# Pair: [1cd] [acd] ->  [3] [9]
# Pair: [12d] [4ac] ->  [4] [8]
# Pair: [12d] [acd] ->  [4] [9]
# Possible pairs for [1d] [ad]
# Pair: [1cd] [acd] ->  [3] [9]
# Pair: [1cd] [abd] ->  [3] [10]
# Pair: [12d] [acd] ->  [4] [9]
# Pair: [12d] [abd] ->  [4] [10]
# Possible pairs for [1d] [bd]
# Pair: [1cd] [abd] ->  [3] [10]
# Pair: [1cd] [bdy] ->  [3] [11]
# Pair: [12d] [abd] ->  [4] [10]
# Pair: [12d] [bdy] ->  [4] [11]
# Possible pairs for [1d] [by]
# Pair: [1cd] [bdy] ->  [3] [11]
# Pair: [12d] [bdy] ->  [4] [11]
# Possible pairs for [4c] [ac]
# Pair: [34c] [4ac] ->  [7] [8]
# Pair: [34c] [acd] ->  [7] [9]
# Pair: [4ac] [4ac] ->  [8] [8]
# Pair: [4ac] [acd] ->  [8] [9]
# Possible pairs for [4c] [ad]
# Pair: [34c] [acd] ->  [7] [9]
# Pair: [34c] [abd] ->  [7] [10]
# Pair: [4ac] [acd] ->  [8] [9]
# Pair: [4ac] [abd] ->  [8] [10]
# Possible pairs for [4c] [bd]
# Pair: [34c] [abd] ->  [7] [10]
# Pair: [34c] [bdy] ->  [7] [11]
# Pair: [4ac] [abd] ->  [8] [10]
# Pair: [4ac] [bdy] ->  [8] [11]
# Possible pairs for [4c] [by]
# Pair: [34c] [bdy] ->  [7] [11]
# Pair: [4ac] [bdy] ->  [8] [11]
# Possible pairs for [ac] [ad]
# Pair: [4ac] [acd] ->  [8] [9]
# Pair: [4ac] [abd] ->  [8] [10]
# Pair: [acd] [acd] ->  [9] [9]
# Pair: [acd] [abd] ->  [9] [10]
# Possible pairs for [ac] [bd]
# Pair: [4ac] [abd] ->  [8] [10]
# Pair: [4ac] [bdy] ->  [8] [11]
# Pair: [acd] [abd] ->  [9] [10]
# Pair: [acd] [bdy] ->  [9] [11]
# Possible pairs for [ac] [by]
# Pair: [4ac] [bdy] ->  [8] [11]
# Pair: [acd] [bdy] ->  [9] [11]
# Possible pairs for [ad] [bd]
# Pair: [acd] [abd] ->  [9] [10]
# Pair: [acd] [bdy] ->  [9] [11]
# Pair: [abd] [abd] ->  [10] [10]
# Pair: [abd] [bdy] ->  [10] [11]
# Possible pairs for [ad] [by]
# Pair: [acd] [bdy] ->  [9] [11]
# Pair: [abd] [bdy] ->  [10] [11]
# Possible pairs for [bd] [by]
# Pair: [abd] [bdy] ->  [10] [11]
# Pair: [bdy] [bdy] ->  [11] [11]
# -------------- In len(list_dict) <= 2 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'abx': {0}, 'abc': {1}, 'bcd': {2}, '1cd': {3}, '12d': {4}, '34c': {7}, '4ac': {8}, 'acd': {9}, 'abd': {10}, 'bdy': {11}})
# No previous dict for i = [3] | cur_len = [3]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'abx': {0}, 'abc': {1}, 'bcd': {2}, '1cd': {3}, '12d': {4}, '34c': {7}, '4ac': {8}, 'acd': {9}, 'abd': {10}, 'bdy': {11}})
# Possible pairs for [abx] [abc]
# Pair: [abcx] [abcx] ->  [0] [0]
# Pair: [abcx] [abcd] ->  [0] [1]
# Possible pairs for [abx] [bcd]
# Pair: [abcx] [abcd] ->  [0] [1]
# Pair: [abcx] [1bcd] ->  [0] [2]
# Possible pairs for [abx] [1cd]
# Pair: [abcx] [1bcd] ->  [0] [2]
# Pair: [abcx] [12cd] ->  [0] [3]
# Possible pairs for [abx] [12d]
# Pair: [abcx] [12cd] ->  [0] [3]
# Pair: [abcx] [123d] ->  [0] [4]
# Possible pairs for [abx] [34c]
# Pair: [abcx] [234c] ->  [0] [6]
# Pair: [abcx] [34ac] ->  [0] [7]
# Possible pairs for [abx] [4ac]
# Pair: [abcx] [34ac] ->  [0] [7]
# Pair: [abcx] [4acd] ->  [0] [8]
# Possible pairs for [abx] [acd]
# Pair: [abcx] [4acd] ->  [0] [8]
# Pair: [abcx] [abcd] ->  [0] [9]
# Possible pairs for [abx] [abd]
# Pair: [abcx] [abcd] ->  [0] [9]
# Pair: [abcx] [abdy] ->  [0] [10]
# Possible pairs for [abx] [bdy]
# Pair: [abcx] [abdy] ->  [0] [10]
# Possible pairs for [abc] [bcd]
# Pair: [abcx] [abcd] ->  [0] [1]
# Pair: [abcx] [1bcd] ->  [0] [2]
# Pair: [abcd] [abcd] ->  [1] [1]
# Pair: [abcd] [1bcd] ->  [1] [2]
# Possible pairs for [abc] [1cd]
# Pair: [abcx] [1bcd] ->  [0] [2]
# Pair: [abcx] [12cd] ->  [0] [3]
# Pair: [abcd] [1bcd] ->  [1] [2]
# Pair: [abcd] [12cd] ->  [1] [3]
# Possible pairs for [abc] [12d]
# Pair: [abcx] [12cd] ->  [0] [3]
# Pair: [abcx] [123d] ->  [0] [4]
# Pair: [abcd] [12cd] ->  [1] [3]
# Pair: [abcd] [123d] ->  [1] [4]
# Possible pairs for [abc] [34c]
# Pair: [abcx] [234c] ->  [0] [6]
# Pair: [abcx] [34ac] ->  [0] [7]
# Pair: [abcd] [234c] ->  [1] [6]
# Pair: [abcd] [34ac] ->  [1] [7]
# Possible pairs for [abc] [4ac]
# Pair: [abcx] [34ac] ->  [0] [7]
# Pair: [abcx] [4acd] ->  [0] [8]
# Pair: [abcd] [34ac] ->  [1] [7]
# Pair: [abcd] [4acd] ->  [1] [8]
# Possible pairs for [abc] [acd]
# Pair: [abcx] [4acd] ->  [0] [8]
# Pair: [abcx] [abcd] ->  [0] [9]
# Pair: [abcd] [4acd] ->  [1] [8]
# Pair: [abcd] [abcd] ->  [1] [9]
# Possible pairs for [abc] [abd]
# Pair: [abcx] [abcd] ->  [0] [9]
# Pair: [abcx] [abdy] ->  [0] [10]
# Pair: [abcd] [abcd] ->  [1] [9]
# Pair: [abcd] [abdy] ->  [1] [10]
# Possible pairs for [abc] [bdy]
# Pair: [abcx] [abdy] ->  [0] [10]
# Pair: [abcd] [abdy] ->  [1] [10]
# Possible pairs for [bcd] [1cd]
# Pair: [abcd] [1bcd] ->  [1] [2]
# Pair: [abcd] [12cd] ->  [1] [3]
# Pair: [1bcd] [1bcd] ->  [2] [2]
# Pair: [1bcd] [12cd] ->  [2] [3]
# Possible pairs for [bcd] [12d]
# Pair: [abcd] [12cd] ->  [1] [3]
# Pair: [abcd] [123d] ->  [1] [4]
# Pair: [1bcd] [12cd] ->  [2] [3]
# Pair: [1bcd] [123d] ->  [2] [4]
# Possible pairs for [bcd] [34c]
# Pair: [abcd] [234c] ->  [1] [6]
# Pair: [abcd] [34ac] ->  [1] [7]
# Pair: [1bcd] [234c] ->  [2] [6]
# Pair: [1bcd] [34ac] ->  [2] [7]
# Possible pairs for [bcd] [4ac]
# Pair: [abcd] [34ac] ->  [1] [7]
# Pair: [abcd] [4acd] ->  [1] [8]
# Pair: [1bcd] [34ac] ->  [2] [7]
# Pair: [1bcd] [4acd] ->  [2] [8]
# Possible pairs for [bcd] [acd]
# Pair: [abcd] [4acd] ->  [1] [8]
# Pair: [abcd] [abcd] ->  [1] [9]
# Pair: [1bcd] [4acd] ->  [2] [8]
# Pair: [1bcd] [abcd] ->  [2] [9]
# Possible pairs for [bcd] [abd]
# Pair: [abcd] [abcd] ->  [1] [9]
# Pair: [abcd] [abdy] ->  [1] [10]
# Pair: [1bcd] [abcd] ->  [2] [9]
# Pair: [1bcd] [abdy] ->  [2] [10]
# Possible pairs for [bcd] [bdy]
# Pair: [abcd] [abdy] ->  [1] [10]
# Pair: [1bcd] [abdy] ->  [2] [10]
# Possible pairs for [1cd] [12d]
# Pair: [1bcd] [12cd] ->  [2] [3]
# Pair: [1bcd] [123d] ->  [2] [4]
# Pair: [12cd] [12cd] ->  [3] [3]
# Pair: [12cd] [123d] ->  [3] [4]
# Possible pairs for [1cd] [34c]
# Pair: [1bcd] [234c] ->  [2] [6]
# Pair: [1bcd] [34ac] ->  [2] [7]
# Pair: [12cd] [234c] ->  [3] [6]
# Pair: [12cd] [34ac] ->  [3] [7]
# Possible pairs for [1cd] [4ac]
# Pair: [1bcd] [34ac] ->  [2] [7]
# Pair: [1bcd] [4acd] ->  [2] [8]
# Pair: [12cd] [34ac] ->  [3] [7]
# Pair: [12cd] [4acd] ->  [3] [8]
# Possible pairs for [1cd] [acd]
# Pair: [1bcd] [4acd] ->  [2] [8]
# Pair: [1bcd] [abcd] ->  [2] [9]
# Pair: [12cd] [4acd] ->  [3] [8]
# Pair: [12cd] [abcd] ->  [3] [9]
# Possible pairs for [1cd] [abd]
# Pair: [1bcd] [abcd] ->  [2] [9]
# Pair: [1bcd] [abdy] ->  [2] [10]
# Pair: [12cd] [abcd] ->  [3] [9]
# Pair: [12cd] [abdy] ->  [3] [10]
# Possible pairs for [1cd] [bdy]
# Pair: [1bcd] [abdy] ->  [2] [10]
# Pair: [12cd] [abdy] ->  [3] [10]
# Possible pairs for [12d] [34c]
# Pair: [12cd] [234c] ->  [3] [6]
# Pair: [12cd] [34ac] ->  [3] [7]
# Pair: [123d] [234c] ->  [4] [6]
# Pair: [123d] [34ac] ->  [4] [7]
# Possible pairs for [12d] [4ac]
# Pair: [12cd] [34ac] ->  [3] [7]
# Pair: [12cd] [4acd] ->  [3] [8]
# Pair: [123d] [34ac] ->  [4] [7]
# Pair: [123d] [4acd] ->  [4] [8]
# Possible pairs for [12d] [acd]
# Pair: [12cd] [4acd] ->  [3] [8]
# Pair: [12cd] [abcd] ->  [3] [9]
# Pair: [123d] [4acd] ->  [4] [8]
# Pair: [123d] [abcd] ->  [4] [9]
# Possible pairs for [12d] [abd]
# Pair: [12cd] [abcd] ->  [3] [9]
# Pair: [12cd] [abdy] ->  [3] [10]
# Pair: [123d] [abcd] ->  [4] [9]
# Pair: [123d] [abdy] ->  [4] [10]
# Possible pairs for [12d] [bdy]
# Pair: [12cd] [abdy] ->  [3] [10]
# Pair: [123d] [abdy] ->  [4] [10]
# Possible pairs for [34c] [4ac]
# Pair: [234c] [34ac] ->  [6] [7]
# Pair: [234c] [4acd] ->  [6] [8]
# Pair: [34ac] [34ac] ->  [7] [7]
# Pair: [34ac] [4acd] ->  [7] [8]
# Possible pairs for [34c] [acd]
# Pair: [234c] [4acd] ->  [6] [8]
# Pair: [234c] [abcd] ->  [6] [9]
# Pair: [34ac] [4acd] ->  [7] [8]
# Pair: [34ac] [abcd] ->  [7] [9]
# Possible pairs for [34c] [abd]
# Pair: [234c] [abcd] ->  [6] [9]
# Pair: [234c] [abdy] ->  [6] [10]
# Pair: [34ac] [abcd] ->  [7] [9]
# Pair: [34ac] [abdy] ->  [7] [10]
# Possible pairs for [34c] [bdy]
# Pair: [234c] [abdy] ->  [6] [10]
# Pair: [34ac] [abdy] ->  [7] [10]
# Possible pairs for [4ac] [acd]
# Pair: [34ac] [4acd] ->  [7] [8]
# Pair: [34ac] [abcd] ->  [7] [9]
# Pair: [4acd] [4acd] ->  [8] [8]
# Pair: [4acd] [abcd] ->  [8] [9]
# Possible pairs for [4ac] [abd]
# Pair: [34ac] [abcd] ->  [7] [9]
# Pair: [34ac] [abdy] ->  [7] [10]
# Pair: [4acd] [abcd] ->  [8] [9]
# Pair: [4acd] [abdy] ->  [8] [10]
# Possible pairs for [4ac] [bdy]
# Pair: [34ac] [abdy] ->  [7] [10]
# Pair: [4acd] [abdy] ->  [8] [10]
# Possible pairs for [acd] [abd]
# Pair: [4acd] [abcd] ->  [8] [9]
# Pair: [4acd] [abdy] ->  [8] [10]
# Pair: [abcd] [abcd] ->  [9] [9]
# Pair: [abcd] [abdy] ->  [9] [10]
# Possible pairs for [acd] [bdy]
# Pair: [4acd] [abdy] ->  [8] [10]
# Pair: [abcd] [abdy] ->  [9] [10]
# Possible pairs for [abd] [bdy]
# Pair: [abcd] [abdy] ->  [9] [10]
# Pair: [abdy] [abdy] ->  [10] [10]
# -------------- In len(list_dict) <= 3 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'abcx': {0}, 'abcd': {1, 9}, '1bcd': {2}, '12cd': {3}, '123d': {4}, '234c': {6}, '34ac': {7}, '4acd': {8}, 'abdy': {10}})
# No previous dict for i = [4] | cur_len = [4]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'abcx': {0}, 'abcd': {1, 9}, '1bcd': {2}, '12cd': {3}, '123d': {4}, '234c': {6}, '34ac': {7}, '4acd': {8}, 'abdy': {10}})
# Possible pairs for [abcx] [abcd]
# Pair: [abcdx] [abcdx] ->  [0] [0]
# Pair: [abcdx] [1abcd] ->  [0] [1]
# Possible pairs for [abcx] [1bcd]
# Pair: [abcdx] [1abcd] ->  [0] [1]
# Pair: [abcdx] [12bcd] ->  [0] [2]
# Possible pairs for [abcx] [12cd]
# Pair: [abcdx] [12bcd] ->  [0] [2]
# Pair: [abcdx] [123cd] ->  [0] [3]
# Possible pairs for [abcx] [123d]
# Pair: [abcdx] [123cd] ->  [0] [3]
# Pair: [abcdx] [1234d] ->  [0] [4]
# Possible pairs for [abcx] [234c]
# Pair: [abcdx] [1234c] ->  [0] [5]
# Pair: [abcdx] [234ac] ->  [0] [6]
# Possible pairs for [abcx] [34ac]
# Pair: [abcdx] [234ac] ->  [0] [6]
# Pair: [abcdx] [34acd] ->  [0] [7]
# Possible pairs for [abcx] [4acd]
# Pair: [abcdx] [34acd] ->  [0] [7]
# Pair: [abcdx] [4abcd] ->  [0] [8]
# Possible pairs for [abcx] [abcd]
# Pair: [abcdx] [4abcd] ->  [0] [8]
# Pair: [abcdx] [abcdy] ->  [0] [9]
# Possible pairs for [abcx] [abdy]
# Pair: [abcdx] [abcdy] ->  [0] [9]
# Possible pairs for [abcd] [1bcd]
# Pair: [abcdx] [1abcd] ->  [0] [1]
# Pair: [abcdx] [12bcd] ->  [0] [2]
# Pair: [1abcd] [1abcd] ->  [1] [1]
# Pair: [1abcd] [12bcd] ->  [1] [2]
# Possible pairs for [abcd] [12cd]
# Pair: [abcdx] [12bcd] ->  [0] [2]
# Pair: [abcdx] [123cd] ->  [0] [3]
# Pair: [1abcd] [12bcd] ->  [1] [2]
# Pair: [1abcd] [123cd] ->  [1] [3]
# Possible pairs for [abcd] [123d]
# Pair: [abcdx] [123cd] ->  [0] [3]
# Pair: [abcdx] [1234d] ->  [0] [4]
# Pair: [1abcd] [123cd] ->  [1] [3]
# Pair: [1abcd] [1234d] ->  [1] [4]
# Possible pairs for [abcd] [234c]
# Pair: [abcdx] [1234c] ->  [0] [5]
# Pair: [abcdx] [234ac] ->  [0] [6]
# Pair: [1abcd] [1234c] ->  [1] [5]
# Pair: [1abcd] [234ac] ->  [1] [6]
# Possible pairs for [abcd] [34ac]
# Pair: [abcdx] [234ac] ->  [0] [6]
# Pair: [abcdx] [34acd] ->  [0] [7]
# Pair: [1abcd] [234ac] ->  [1] [6]
# Pair: [1abcd] [34acd] ->  [1] [7]
# Possible pairs for [abcd] [4acd]
# Pair: [abcdx] [34acd] ->  [0] [7]
# Pair: [abcdx] [4abcd] ->  [0] [8]
# Pair: [1abcd] [34acd] ->  [1] [7]
# Pair: [1abcd] [4abcd] ->  [1] [8]
# Possible pairs for [abcd] [abcd]
# Pair: [abcdx] [4abcd] ->  [0] [8]
# Pair: [abcdx] [abcdy] ->  [0] [9]
# Pair: [1abcd] [4abcd] ->  [1] [8]
# Pair: [1abcd] [abcdy] ->  [1] [9]
# Possible pairs for [abcd] [abdy]
# Pair: [abcdx] [abcdy] ->  [0] [9]
# Pair: [1abcd] [abcdy] ->  [1] [9]
# Possible pairs for [1bcd] [12cd]
# Pair: [1abcd] [12bcd] ->  [1] [2]
# Pair: [1abcd] [123cd] ->  [1] [3]
# Pair: [12bcd] [12bcd] ->  [2] [2]
# Pair: [12bcd] [123cd] ->  [2] [3]
# Possible pairs for [1bcd] [123d]
# Pair: [1abcd] [123cd] ->  [1] [3]
# Pair: [1abcd] [1234d] ->  [1] [4]
# Pair: [12bcd] [123cd] ->  [2] [3]
# Pair: [12bcd] [1234d] ->  [2] [4]
# Possible pairs for [1bcd] [234c]
# Pair: [1abcd] [1234c] ->  [1] [5]
# Pair: [1abcd] [234ac] ->  [1] [6]
# Pair: [12bcd] [1234c] ->  [2] [5]
# Pair: [12bcd] [234ac] ->  [2] [6]
# Possible pairs for [1bcd] [34ac]
# Pair: [1abcd] [234ac] ->  [1] [6]
# Pair: [1abcd] [34acd] ->  [1] [7]
# Pair: [12bcd] [234ac] ->  [2] [6]
# Pair: [12bcd] [34acd] ->  [2] [7]
# Possible pairs for [1bcd] [4acd]
# Pair: [1abcd] [34acd] ->  [1] [7]
# Pair: [1abcd] [4abcd] ->  [1] [8]
# Pair: [12bcd] [34acd] ->  [2] [7]
# Pair: [12bcd] [4abcd] ->  [2] [8]
# Possible pairs for [1bcd] [abcd]
# Pair: [1abcd] [4abcd] ->  [1] [8]
# Pair: [1abcd] [abcdy] ->  [1] [9]
# Pair: [12bcd] [4abcd] ->  [2] [8]
# Pair: [12bcd] [abcdy] ->  [2] [9]
# Possible pairs for [1bcd] [abdy]
# Pair: [1abcd] [abcdy] ->  [1] [9]
# Pair: [12bcd] [abcdy] ->  [2] [9]
# Possible pairs for [12cd] [123d]
# Pair: [12bcd] [123cd] ->  [2] [3]
# Pair: [12bcd] [1234d] ->  [2] [4]
# Pair: [123cd] [123cd] ->  [3] [3]
# Pair: [123cd] [1234d] ->  [3] [4]
# Possible pairs for [12cd] [234c]
# Pair: [12bcd] [1234c] ->  [2] [5]
# Pair: [12bcd] [234ac] ->  [2] [6]
# Pair: [123cd] [1234c] ->  [3] [5]
# Pair: [123cd] [234ac] ->  [3] [6]
# Possible pairs for [12cd] [34ac]
# Pair: [12bcd] [234ac] ->  [2] [6]
# Pair: [12bcd] [34acd] ->  [2] [7]
# Pair: [123cd] [234ac] ->  [3] [6]
# Pair: [123cd] [34acd] ->  [3] [7]
# Possible pairs for [12cd] [4acd]
# Pair: [12bcd] [34acd] ->  [2] [7]
# Pair: [12bcd] [4abcd] ->  [2] [8]
# Pair: [123cd] [34acd] ->  [3] [7]
# Pair: [123cd] [4abcd] ->  [3] [8]
# Possible pairs for [12cd] [abcd]
# Pair: [12bcd] [4abcd] ->  [2] [8]
# Pair: [12bcd] [abcdy] ->  [2] [9]
# Pair: [123cd] [4abcd] ->  [3] [8]
# Pair: [123cd] [abcdy] ->  [3] [9]
# Possible pairs for [12cd] [abdy]
# Pair: [12bcd] [abcdy] ->  [2] [9]
# Pair: [123cd] [abcdy] ->  [3] [9]
# Possible pairs for [123d] [234c]
# Pair: [123cd] [1234c] ->  [3] [5]
# Pair: [123cd] [234ac] ->  [3] [6]
# Pair: [1234d] [1234c] ->  [4] [5]
# Pair: [1234d] [234ac] ->  [4] [6]
# Possible pairs for [123d] [34ac]
# Pair: [123cd] [234ac] ->  [3] [6]
# Pair: [123cd] [34acd] ->  [3] [7]
# Pair: [1234d] [234ac] ->  [4] [6]
# Pair: [1234d] [34acd] ->  [4] [7]
# Possible pairs for [123d] [4acd]
# Pair: [123cd] [34acd] ->  [3] [7]
# Pair: [123cd] [4abcd] ->  [3] [8]
# Pair: [1234d] [34acd] ->  [4] [7]
# Pair: [1234d] [4abcd] ->  [4] [8]
# Possible pairs for [123d] [abcd]
# Pair: [123cd] [4abcd] ->  [3] [8]
# Pair: [123cd] [abcdy] ->  [3] [9]
# Pair: [1234d] [4abcd] ->  [4] [8]
# Pair: [1234d] [abcdy] ->  [4] [9]
# Possible pairs for [123d] [abdy]
# Pair: [123cd] [abcdy] ->  [3] [9]
# Pair: [1234d] [abcdy] ->  [4] [9]
# Possible pairs for [234c] [34ac]
# Pair: [1234c] [234ac] ->  [5] [6]
# Pair: [1234c] [34acd] ->  [5] [7]
# Pair: [234ac] [234ac] ->  [6] [6]
# Pair: [234ac] [34acd] ->  [6] [7]
# Possible pairs for [234c] [4acd]
# Pair: [1234c] [34acd] ->  [5] [7]
# Pair: [1234c] [4abcd] ->  [5] [8]
# Pair: [234ac] [34acd] ->  [6] [7]
# Pair: [234ac] [4abcd] ->  [6] [8]
# Possible pairs for [234c] [abcd]
# Pair: [1234c] [4abcd] ->  [5] [8]
# Pair: [1234c] [abcdy] ->  [5] [9]
# Pair: [234ac] [4abcd] ->  [6] [8]
# Pair: [234ac] [abcdy] ->  [6] [9]
# Possible pairs for [234c] [abdy]
# Pair: [1234c] [abcdy] ->  [5] [9]
# Pair: [234ac] [abcdy] ->  [6] [9]
# Possible pairs for [34ac] [4acd]
# Pair: [234ac] [34acd] ->  [6] [7]
# Pair: [234ac] [4abcd] ->  [6] [8]
# Pair: [34acd] [34acd] ->  [7] [7]
# Pair: [34acd] [4abcd] ->  [7] [8]
# Possible pairs for [34ac] [abcd]
# Pair: [234ac] [4abcd] ->  [6] [8]
# Pair: [234ac] [abcdy] ->  [6] [9]
# Pair: [34acd] [4abcd] ->  [7] [8]
# Pair: [34acd] [abcdy] ->  [7] [9]
# Possible pairs for [34ac] [abdy]
# Pair: [234ac] [abcdy] ->  [6] [9]
# Pair: [34acd] [abcdy] ->  [7] [9]
# Possible pairs for [4acd] [abcd]
# Pair: [34acd] [4abcd] ->  [7] [8]
# Pair: [34acd] [abcdy] ->  [7] [9]
# Pair: [4abcd] [4abcd] ->  [8] [8]
# Pair: [4abcd] [abcdy] ->  [8] [9]
# Possible pairs for [4acd] [abdy]
# Pair: [34acd] [abcdy] ->  [7] [9]
# Pair: [4abcd] [abcdy] ->  [8] [9]
# Possible pairs for [abcd] [abdy]
# Pair: [4abcd] [abcdy] ->  [8] [9]
# Pair: [abcdy] [abcdy] ->  [9] [9]
# -------------- In len(list_dict) <= 4 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'abcdx': {0}, '1abcd': {1}, '12bcd': {2}, '123cd': {3}, '1234d': {4}, '1234c': {5}, '234ac': {6}, '34acd': {7}, '4abcd': {8}, 'abcdy': {9}})
# No previous dict for i = [5] | cur_len = [5]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'abcdx': {0}, '1abcd': {1}, '12bcd': {2}, '123cd': {3}, '1234d': {4}, '1234c': {5}, '234ac': {6}, '34acd': {7}, '4abcd': {8}, 'abcdy': {9}})
# Possible pairs for [abcdx] [1abcd]
# Pair: [1abcdx] [1abcdx] ->  [0] [0]
# Pair: [1abcdx] [12abcd] ->  [0] [1]
# Possible pairs for [abcdx] [12bcd]
# Pair: [1abcdx] [12abcd] ->  [0] [1]
# Pair: [1abcdx] [123bcd] ->  [0] [2]
# Possible pairs for [abcdx] [123cd]
# Pair: [1abcdx] [123bcd] ->  [0] [2]
# Pair: [1abcdx] [1234cd] ->  [0] [3]
# Possible pairs for [abcdx] [1234d]
# Pair: [1abcdx] [1234cd] ->  [0] [3]
# Pair: [1abcdx] [1234cd] ->  [0] [4]
# Possible pairs for [abcdx] [1234c]
# Pair: [1abcdx] [1234cd] ->  [0] [4]
# Pair: [1abcdx] [1234ac] ->  [0] [5]
# Possible pairs for [abcdx] [234ac]
# Pair: [1abcdx] [1234ac] ->  [0] [5]
# Pair: [1abcdx] [234acd] ->  [0] [6]
# Possible pairs for [abcdx] [34acd]
# Pair: [1abcdx] [234acd] ->  [0] [6]
# Pair: [1abcdx] [34abcd] ->  [0] [7]
# Possible pairs for [abcdx] [4abcd]
# Pair: [1abcdx] [34abcd] ->  [0] [7]
# Pair: [1abcdx] [4abcdy] ->  [0] [8]
# Possible pairs for [abcdx] [abcdy]
# Pair: [1abcdx] [4abcdy] ->  [0] [8]
# Possible pairs for [1abcd] [12bcd]
# Pair: [1abcdx] [12abcd] ->  [0] [1]
# Pair: [1abcdx] [123bcd] ->  [0] [2]
# Pair: [12abcd] [12abcd] ->  [1] [1]
# Pair: [12abcd] [123bcd] ->  [1] [2]
# Possible pairs for [1abcd] [123cd]
# Pair: [1abcdx] [123bcd] ->  [0] [2]
# Pair: [1abcdx] [1234cd] ->  [0] [3]
# Pair: [12abcd] [123bcd] ->  [1] [2]
# Pair: [12abcd] [1234cd] ->  [1] [3]
# Possible pairs for [1abcd] [1234d]
# Pair: [1abcdx] [1234cd] ->  [0] [3]
# Pair: [1abcdx] [1234cd] ->  [0] [4]
# Pair: [12abcd] [1234cd] ->  [1] [3]
# Pair: [12abcd] [1234cd] ->  [1] [4]
# Possible pairs for [1abcd] [1234c]
# Pair: [1abcdx] [1234cd] ->  [0] [4]
# Pair: [1abcdx] [1234ac] ->  [0] [5]
# Pair: [12abcd] [1234cd] ->  [1] [4]
# Pair: [12abcd] [1234ac] ->  [1] [5]
# Possible pairs for [1abcd] [234ac]
# Pair: [1abcdx] [1234ac] ->  [0] [5]
# Pair: [1abcdx] [234acd] ->  [0] [6]
# Pair: [12abcd] [1234ac] ->  [1] [5]
# Pair: [12abcd] [234acd] ->  [1] [6]
# Possible pairs for [1abcd] [34acd]
# Pair: [1abcdx] [234acd] ->  [0] [6]
# Pair: [1abcdx] [34abcd] ->  [0] [7]
# Pair: [12abcd] [234acd] ->  [1] [6]
# Pair: [12abcd] [34abcd] ->  [1] [7]
# Possible pairs for [1abcd] [4abcd]
# Pair: [1abcdx] [34abcd] ->  [0] [7]
# Pair: [1abcdx] [4abcdy] ->  [0] [8]
# Pair: [12abcd] [34abcd] ->  [1] [7]
# Pair: [12abcd] [4abcdy] ->  [1] [8]
# Possible pairs for [1abcd] [abcdy]
# Pair: [1abcdx] [4abcdy] ->  [0] [8]
# Pair: [12abcd] [4abcdy] ->  [1] [8]
# Possible pairs for [12bcd] [123cd]
# Pair: [12abcd] [123bcd] ->  [1] [2]
# Pair: [12abcd] [1234cd] ->  [1] [3]
# Pair: [123bcd] [123bcd] ->  [2] [2]
# Pair: [123bcd] [1234cd] ->  [2] [3]
# Possible pairs for [12bcd] [1234d]
# Pair: [12abcd] [1234cd] ->  [1] [3]
# Pair: [12abcd] [1234cd] ->  [1] [4]
# Pair: [123bcd] [1234cd] ->  [2] [3]
# Pair: [123bcd] [1234cd] ->  [2] [4]
# Possible pairs for [12bcd] [1234c]
# Pair: [12abcd] [1234cd] ->  [1] [4]
# Pair: [12abcd] [1234ac] ->  [1] [5]
# Pair: [123bcd] [1234cd] ->  [2] [4]
# Pair: [123bcd] [1234ac] ->  [2] [5]
# Possible pairs for [12bcd] [234ac]
# Pair: [12abcd] [1234ac] ->  [1] [5]
# Pair: [12abcd] [234acd] ->  [1] [6]
# Pair: [123bcd] [1234ac] ->  [2] [5]
# Pair: [123bcd] [234acd] ->  [2] [6]
# Possible pairs for [12bcd] [34acd]
# Pair: [12abcd] [234acd] ->  [1] [6]
# Pair: [12abcd] [34abcd] ->  [1] [7]
# Pair: [123bcd] [234acd] ->  [2] [6]
# Pair: [123bcd] [34abcd] ->  [2] [7]
# Possible pairs for [12bcd] [4abcd]
# Pair: [12abcd] [34abcd] ->  [1] [7]
# Pair: [12abcd] [4abcdy] ->  [1] [8]
# Pair: [123bcd] [34abcd] ->  [2] [7]
# Pair: [123bcd] [4abcdy] ->  [2] [8]
# Possible pairs for [12bcd] [abcdy]
# Pair: [12abcd] [4abcdy] ->  [1] [8]
# Pair: [123bcd] [4abcdy] ->  [2] [8]
# Possible pairs for [123cd] [1234d]
# Pair: [123bcd] [1234cd] ->  [2] [3]
# Pair: [123bcd] [1234cd] ->  [2] [4]
# Pair: [1234cd] [1234cd] ->  [3] [3]
# Pair: [1234cd] [1234cd] ->  [3] [4]
# Possible pairs for [123cd] [1234c]
# Pair: [123bcd] [1234cd] ->  [2] [4]
# Pair: [123bcd] [1234ac] ->  [2] [5]
# Pair: [1234cd] [1234cd] ->  [3] [4]
# Pair: [1234cd] [1234ac] ->  [3] [5]
# Possible pairs for [123cd] [234ac]
# Pair: [123bcd] [1234ac] ->  [2] [5]
# Pair: [123bcd] [234acd] ->  [2] [6]
# Pair: [1234cd] [1234ac] ->  [3] [5]
# Pair: [1234cd] [234acd] ->  [3] [6]
# Possible pairs for [123cd] [34acd]
# Pair: [123bcd] [234acd] ->  [2] [6]
# Pair: [123bcd] [34abcd] ->  [2] [7]
# Pair: [1234cd] [234acd] ->  [3] [6]
# Pair: [1234cd] [34abcd] ->  [3] [7]
# Possible pairs for [123cd] [4abcd]
# Pair: [123bcd] [34abcd] ->  [2] [7]
# Pair: [123bcd] [4abcdy] ->  [2] [8]
# Pair: [1234cd] [34abcd] ->  [3] [7]
# Pair: [1234cd] [4abcdy] ->  [3] [8]
# Possible pairs for [123cd] [abcdy]
# Pair: [123bcd] [4abcdy] ->  [2] [8]
# Pair: [1234cd] [4abcdy] ->  [3] [8]
# Possible pairs for [1234d] [1234c]
# Pair: [1234cd] [1234cd] ->  [3] [4]
# Pair: [1234cd] [1234ac] ->  [3] [5]
# Pair: [1234cd] [1234cd] ->  [4] [4]
# Pair: [1234cd] [1234ac] ->  [4] [5]
# Possible pairs for [1234d] [234ac]
# Pair: [1234cd] [1234ac] ->  [3] [5]
# Pair: [1234cd] [234acd] ->  [3] [6]
# Pair: [1234cd] [1234ac] ->  [4] [5]
# Pair: [1234cd] [234acd] ->  [4] [6]
# Possible pairs for [1234d] [34acd]
# Pair: [1234cd] [234acd] ->  [3] [6]
# Pair: [1234cd] [34abcd] ->  [3] [7]
# Pair: [1234cd] [234acd] ->  [4] [6]
# Pair: [1234cd] [34abcd] ->  [4] [7]
# Possible pairs for [1234d] [4abcd]
# Pair: [1234cd] [34abcd] ->  [3] [7]
# Pair: [1234cd] [4abcdy] ->  [3] [8]
# Pair: [1234cd] [34abcd] ->  [4] [7]
# Pair: [1234cd] [4abcdy] ->  [4] [8]
# Possible pairs for [1234d] [abcdy]
# Pair: [1234cd] [4abcdy] ->  [3] [8]
# Pair: [1234cd] [4abcdy] ->  [4] [8]
# Possible pairs for [1234c] [234ac]
# Pair: [1234cd] [1234ac] ->  [4] [5]
# Pair: [1234cd] [234acd] ->  [4] [6]
# Pair: [1234ac] [1234ac] ->  [5] [5]
# Pair: [1234ac] [234acd] ->  [5] [6]
# Possible pairs for [1234c] [34acd]
# Pair: [1234cd] [234acd] ->  [4] [6]
# Pair: [1234cd] [34abcd] ->  [4] [7]
# Pair: [1234ac] [234acd] ->  [5] [6]
# Pair: [1234ac] [34abcd] ->  [5] [7]
# Possible pairs for [1234c] [4abcd]
# Pair: [1234cd] [34abcd] ->  [4] [7]
# Pair: [1234cd] [4abcdy] ->  [4] [8]
# Pair: [1234ac] [34abcd] ->  [5] [7]
# Pair: [1234ac] [4abcdy] ->  [5] [8]
# Possible pairs for [1234c] [abcdy]
# Pair: [1234cd] [4abcdy] ->  [4] [8]
# Pair: [1234ac] [4abcdy] ->  [5] [8]
# Possible pairs for [234ac] [34acd]
# Pair: [1234ac] [234acd] ->  [5] [6]
# Pair: [1234ac] [34abcd] ->  [5] [7]
# Pair: [234acd] [234acd] ->  [6] [6]
# Pair: [234acd] [34abcd] ->  [6] [7]
# Possible pairs for [234ac] [4abcd]
# Pair: [1234ac] [34abcd] ->  [5] [7]
# Pair: [1234ac] [4abcdy] ->  [5] [8]
# Pair: [234acd] [34abcd] ->  [6] [7]
# Pair: [234acd] [4abcdy] ->  [6] [8]
# Possible pairs for [234ac] [abcdy]
# Pair: [1234ac] [4abcdy] ->  [5] [8]
# Pair: [234acd] [4abcdy] ->  [6] [8]
# Possible pairs for [34acd] [4abcd]
# Pair: [234acd] [34abcd] ->  [6] [7]
# Pair: [234acd] [4abcdy] ->  [6] [8]
# Pair: [34abcd] [34abcd] ->  [7] [7]
# Pair: [34abcd] [4abcdy] ->  [7] [8]
# Possible pairs for [34acd] [abcdy]
# Pair: [234acd] [4abcdy] ->  [6] [8]
# Pair: [34abcd] [4abcdy] ->  [7] [8]
# Possible pairs for [4abcd] [abcdy]
# Pair: [34abcd] [4abcdy] ->  [7] [8]
# Pair: [4abcdy] [4abcdy] ->  [8] [8]
# -------------- In len(list_dict) <= 5 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'1abcdx': {0}, '12abcd': {1}, '123bcd': {2}, '1234cd': {3, 4}, '1234ac': {5}, '234acd': {6}, '34abcd': {7}, '4abcdy': {8}})
# No previous dict for i = [6] | cur_len = [6]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'1abcdx': {0}, '12abcd': {1}, '123bcd': {2}, '1234cd': {3, 4}, '1234ac': {5}, '234acd': {6}, '34abcd': {7}, '4abcdy': {8}})
# Possible pairs for [1abcdx] [12abcd]
# Pair: [12abcdx] [12abcdx] ->  [0] [0]
# Pair: [12abcdx] [123abcd] ->  [0] [1]
# Possible pairs for [1abcdx] [123bcd]
# Pair: [12abcdx] [123abcd] ->  [0] [1]
# Pair: [12abcdx] [1234bcd] ->  [0] [2]
# Possible pairs for [1abcdx] [1234cd]
# Pair: [12abcdx] [1234bcd] ->  [0] [2]
# Pair: [12abcdx] [1234ccd] ->  [0] [3]
# Possible pairs for [1abcdx] [1234cd]
# Pair: [12abcdx] [1234ccd] ->  [0] [3]
# Pair: [12abcdx] [1234acd] ->  [0] [4]
# Possible pairs for [1abcdx] [1234ac]
# Pair: [12abcdx] [1234acd] ->  [0] [4]
# Pair: [12abcdx] [1234acd] ->  [0] [5]
# Possible pairs for [1abcdx] [234acd]
# Pair: [12abcdx] [1234acd] ->  [0] [5]
# Pair: [12abcdx] [234abcd] ->  [0] [6]
# Possible pairs for [1abcdx] [34abcd]
# Pair: [12abcdx] [234abcd] ->  [0] [6]
# Pair: [12abcdx] [34abcdy] ->  [0] [7]
# Possible pairs for [1abcdx] [4abcdy]
# Pair: [12abcdx] [34abcdy] ->  [0] [7]
# Possible pairs for [12abcd] [123bcd]
# Pair: [12abcdx] [123abcd] ->  [0] [1]
# Pair: [12abcdx] [1234bcd] ->  [0] [2]
# Pair: [123abcd] [123abcd] ->  [1] [1]
# Pair: [123abcd] [1234bcd] ->  [1] [2]
# Possible pairs for [12abcd] [1234cd]
# Pair: [12abcdx] [1234bcd] ->  [0] [2]
# Pair: [12abcdx] [1234ccd] ->  [0] [3]
# Pair: [123abcd] [1234bcd] ->  [1] [2]
# Pair: [123abcd] [1234ccd] ->  [1] [3]
# Possible pairs for [12abcd] [1234cd]
# Pair: [12abcdx] [1234ccd] ->  [0] [3]
# Pair: [12abcdx] [1234acd] ->  [0] [4]
# Pair: [123abcd] [1234ccd] ->  [1] [3]
# Pair: [123abcd] [1234acd] ->  [1] [4]
# Possible pairs for [12abcd] [1234ac]
# Pair: [12abcdx] [1234acd] ->  [0] [4]
# Pair: [12abcdx] [1234acd] ->  [0] [5]
# Pair: [123abcd] [1234acd] ->  [1] [4]
# Pair: [123abcd] [1234acd] ->  [1] [5]
# Possible pairs for [12abcd] [234acd]
# Pair: [12abcdx] [1234acd] ->  [0] [5]
# Pair: [12abcdx] [234abcd] ->  [0] [6]
# Pair: [123abcd] [1234acd] ->  [1] [5]
# Pair: [123abcd] [234abcd] ->  [1] [6]
# Possible pairs for [12abcd] [34abcd]
# Pair: [12abcdx] [234abcd] ->  [0] [6]
# Pair: [12abcdx] [34abcdy] ->  [0] [7]
# Pair: [123abcd] [234abcd] ->  [1] [6]
# Pair: [123abcd] [34abcdy] ->  [1] [7]
# Possible pairs for [12abcd] [4abcdy]
# Pair: [12abcdx] [34abcdy] ->  [0] [7]
# Pair: [123abcd] [34abcdy] ->  [1] [7]
# Possible pairs for [123bcd] [1234cd]
# Pair: [123abcd] [1234bcd] ->  [1] [2]
# Pair: [123abcd] [1234ccd] ->  [1] [3]
# Pair: [1234bcd] [1234bcd] ->  [2] [2]
# Pair: [1234bcd] [1234ccd] ->  [2] [3]
# Possible pairs for [123bcd] [1234cd]
# Pair: [123abcd] [1234ccd] ->  [1] [3]
# Pair: [123abcd] [1234acd] ->  [1] [4]
# Pair: [1234bcd] [1234ccd] ->  [2] [3]
# Pair: [1234bcd] [1234acd] ->  [2] [4]
# Possible pairs for [123bcd] [1234ac]
# Pair: [123abcd] [1234acd] ->  [1] [4]
# Pair: [123abcd] [1234acd] ->  [1] [5]
# Pair: [1234bcd] [1234acd] ->  [2] [4]
# Pair: [1234bcd] [1234acd] ->  [2] [5]
# Possible pairs for [123bcd] [234acd]
# Pair: [123abcd] [1234acd] ->  [1] [5]
# Pair: [123abcd] [234abcd] ->  [1] [6]
# Pair: [1234bcd] [1234acd] ->  [2] [5]
# Pair: [1234bcd] [234abcd] ->  [2] [6]
# Possible pairs for [123bcd] [34abcd]
# Pair: [123abcd] [234abcd] ->  [1] [6]
# Pair: [123abcd] [34abcdy] ->  [1] [7]
# Pair: [1234bcd] [234abcd] ->  [2] [6]
# Pair: [1234bcd] [34abcdy] ->  [2] [7]
# Possible pairs for [123bcd] [4abcdy]
# Pair: [123abcd] [34abcdy] ->  [1] [7]
# Pair: [1234bcd] [34abcdy] ->  [2] [7]
# Possible pairs for [1234cd] [1234cd]
# Pair: [1234bcd] [1234ccd] ->  [2] [3]
# Pair: [1234bcd] [1234acd] ->  [2] [4]
# Pair: [1234ccd] [1234ccd] ->  [3] [3]
# Pair: [1234ccd] [1234acd] ->  [3] [4]
# Possible pairs for [1234cd] [1234ac]
# Pair: [1234bcd] [1234acd] ->  [2] [4]
# Pair: [1234bcd] [1234acd] ->  [2] [5]
# Pair: [1234ccd] [1234acd] ->  [3] [4]
# Pair: [1234ccd] [1234acd] ->  [3] [5]
# Possible pairs for [1234cd] [234acd]
# Pair: [1234bcd] [1234acd] ->  [2] [5]
# Pair: [1234bcd] [234abcd] ->  [2] [6]
# Pair: [1234ccd] [1234acd] ->  [3] [5]
# Pair: [1234ccd] [234abcd] ->  [3] [6]
# Possible pairs for [1234cd] [34abcd]
# Pair: [1234bcd] [234abcd] ->  [2] [6]
# Pair: [1234bcd] [34abcdy] ->  [2] [7]
# Pair: [1234ccd] [234abcd] ->  [3] [6]
# Pair: [1234ccd] [34abcdy] ->  [3] [7]
# Possible pairs for [1234cd] [4abcdy]
# Pair: [1234bcd] [34abcdy] ->  [2] [7]
# Pair: [1234ccd] [34abcdy] ->  [3] [7]
# Possible pairs for [1234cd] [1234ac]
# Pair: [1234ccd] [1234acd] ->  [3] [4]
# Pair: [1234ccd] [1234acd] ->  [3] [5]
# Pair: [1234acd] [1234acd] ->  [4] [4]
# Pair: [1234acd] [1234acd] ->  [4] [5]
# Possible pairs for [1234cd] [234acd]
# Pair: [1234ccd] [1234acd] ->  [3] [5]
# Pair: [1234ccd] [234abcd] ->  [3] [6]
# Pair: [1234acd] [1234acd] ->  [4] [5]
# Pair: [1234acd] [234abcd] ->  [4] [6]
# Possible pairs for [1234cd] [34abcd]
# Pair: [1234ccd] [234abcd] ->  [3] [6]
# Pair: [1234ccd] [34abcdy] ->  [3] [7]
# Pair: [1234acd] [234abcd] ->  [4] [6]
# Pair: [1234acd] [34abcdy] ->  [4] [7]
# Possible pairs for [1234cd] [4abcdy]
# Pair: [1234ccd] [34abcdy] ->  [3] [7]
# Pair: [1234acd] [34abcdy] ->  [4] [7]
# Possible pairs for [1234ac] [234acd]
# Pair: [1234acd] [1234acd] ->  [4] [5]
# Pair: [1234acd] [234abcd] ->  [4] [6]
# Pair: [1234acd] [1234acd] ->  [5] [5]
# Pair: [1234acd] [234abcd] ->  [5] [6]
# Possible pairs for [1234ac] [34abcd]
# Pair: [1234acd] [234abcd] ->  [4] [6]
# Pair: [1234acd] [34abcdy] ->  [4] [7]
# Pair: [1234acd] [234abcd] ->  [5] [6]
# Pair: [1234acd] [34abcdy] ->  [5] [7]
# Possible pairs for [1234ac] [4abcdy]
# Pair: [1234acd] [34abcdy] ->  [4] [7]
# Pair: [1234acd] [34abcdy] ->  [5] [7]
# Possible pairs for [234acd] [34abcd]
# Pair: [1234acd] [234abcd] ->  [5] [6]
# Pair: [1234acd] [34abcdy] ->  [5] [7]
# Pair: [234abcd] [234abcd] ->  [6] [6]
# Pair: [234abcd] [34abcdy] ->  [6] [7]
# Possible pairs for [234acd] [4abcdy]
# Pair: [1234acd] [34abcdy] ->  [5] [7]
# Pair: [234abcd] [34abcdy] ->  [6] [7]
# Possible pairs for [34abcd] [4abcdy]
# Pair: [234abcd] [34abcdy] ->  [6] [7]
# Pair: [34abcdy] [34abcdy] ->  [7] [7]
# -------------- In len(list_dict) <= 6 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'12abcdx': {0}, '123abcd': {1}, '1234bcd': {2}, '1234ccd': {3}, '1234acd': {4, 5}, '234abcd': {6}, '34abcdy': {7}})
# No previous dict for i = [7] | cur_len = [7]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'12abcdx': {0}, '123abcd': {1}, '1234bcd': {2}, '1234ccd': {3}, '1234acd': {4, 5}, '234abcd': {6}, '34abcdy': {7}})
# Possible pairs for [12abcdx] [123abcd]
# Pair: [123abcdx] [123abcdx] ->  [0] [0]
# Pair: [123abcdx] [1234abcd] ->  [0] [1]
# Possible pairs for [12abcdx] [1234bcd]
# Pair: [123abcdx] [1234abcd] ->  [0] [1]
# Pair: [123abcdx] [1234bccd] ->  [0] [2]
# Possible pairs for [12abcdx] [1234ccd]
# Pair: [123abcdx] [1234bccd] ->  [0] [2]
# Pair: [123abcdx] [1234accd] ->  [0] [3]
# Possible pairs for [12abcdx] [1234acd]
# Pair: [123abcdx] [1234accd] ->  [0] [3]
# Pair: [123abcdx] [1234acdd] ->  [0] [4]
# Possible pairs for [12abcdx] [1234acd]
# Pair: [123abcdx] [1234acdd] ->  [0] [4]
# Pair: [123abcdx] [1234abcd] ->  [0] [5]
# Possible pairs for [12abcdx] [234abcd]
# Pair: [123abcdx] [1234abcd] ->  [0] [5]
# Pair: [123abcdx] [234abcdy] ->  [0] [6]
# Possible pairs for [12abcdx] [34abcdy]
# Pair: [123abcdx] [234abcdy] ->  [0] [6]
# Possible pairs for [123abcd] [1234bcd]
# Pair: [123abcdx] [1234abcd] ->  [0] [1]
# Pair: [123abcdx] [1234bccd] ->  [0] [2]
# Pair: [1234abcd] [1234abcd] ->  [1] [1]
# Pair: [1234abcd] [1234bccd] ->  [1] [2]
# Possible pairs for [123abcd] [1234ccd]
# Pair: [123abcdx] [1234bccd] ->  [0] [2]
# Pair: [123abcdx] [1234accd] ->  [0] [3]
# Pair: [1234abcd] [1234bccd] ->  [1] [2]
# Pair: [1234abcd] [1234accd] ->  [1] [3]
# Possible pairs for [123abcd] [1234acd]
# Pair: [123abcdx] [1234accd] ->  [0] [3]
# Pair: [123abcdx] [1234acdd] ->  [0] [4]
# Pair: [1234abcd] [1234accd] ->  [1] [3]
# Pair: [1234abcd] [1234acdd] ->  [1] [4]
# Possible pairs for [123abcd] [1234acd]
# Pair: [123abcdx] [1234acdd] ->  [0] [4]
# Pair: [123abcdx] [1234abcd] ->  [0] [5]
# Pair: [1234abcd] [1234acdd] ->  [1] [4]
# Pair: [1234abcd] [1234abcd] ->  [1] [5]
# Possible pairs for [123abcd] [234abcd]
# Pair: [123abcdx] [1234abcd] ->  [0] [5]
# Pair: [123abcdx] [234abcdy] ->  [0] [6]
# Pair: [1234abcd] [1234abcd] ->  [1] [5]
# Pair: [1234abcd] [234abcdy] ->  [1] [6]
# Possible pairs for [123abcd] [34abcdy]
# Pair: [123abcdx] [234abcdy] ->  [0] [6]
# Pair: [1234abcd] [234abcdy] ->  [1] [6]
# Possible pairs for [1234bcd] [1234ccd]
# Pair: [1234abcd] [1234bccd] ->  [1] [2]
# Pair: [1234abcd] [1234accd] ->  [1] [3]
# Pair: [1234bccd] [1234bccd] ->  [2] [2]
# Pair: [1234bccd] [1234accd] ->  [2] [3]
# Possible pairs for [1234bcd] [1234acd]
# Pair: [1234abcd] [1234accd] ->  [1] [3]
# Pair: [1234abcd] [1234acdd] ->  [1] [4]
# Pair: [1234bccd] [1234accd] ->  [2] [3]
# Pair: [1234bccd] [1234acdd] ->  [2] [4]
# Possible pairs for [1234bcd] [1234acd]
# Pair: [1234abcd] [1234acdd] ->  [1] [4]
# Pair: [1234abcd] [1234abcd] ->  [1] [5]
# Pair: [1234bccd] [1234acdd] ->  [2] [4]
# Pair: [1234bccd] [1234abcd] ->  [2] [5]
# Possible pairs for [1234bcd] [234abcd]
# Pair: [1234abcd] [1234abcd] ->  [1] [5]
# Pair: [1234abcd] [234abcdy] ->  [1] [6]
# Pair: [1234bccd] [1234abcd] ->  [2] [5]
# Pair: [1234bccd] [234abcdy] ->  [2] [6]
# Possible pairs for [1234bcd] [34abcdy]
# Pair: [1234abcd] [234abcdy] ->  [1] [6]
# Pair: [1234bccd] [234abcdy] ->  [2] [6]
# Possible pairs for [1234ccd] [1234acd]
# Pair: [1234bccd] [1234accd] ->  [2] [3]
# Pair: [1234bccd] [1234acdd] ->  [2] [4]
# Pair: [1234accd] [1234accd] ->  [3] [3]
# Pair: [1234accd] [1234acdd] ->  [3] [4]
# Possible pairs for [1234ccd] [1234acd]
# Pair: [1234bccd] [1234acdd] ->  [2] [4]
# Pair: [1234bccd] [1234abcd] ->  [2] [5]
# Pair: [1234accd] [1234acdd] ->  [3] [4]
# Pair: [1234accd] [1234abcd] ->  [3] [5]
# Possible pairs for [1234ccd] [234abcd]
# Pair: [1234bccd] [1234abcd] ->  [2] [5]
# Pair: [1234bccd] [234abcdy] ->  [2] [6]
# Pair: [1234accd] [1234abcd] ->  [3] [5]
# Pair: [1234accd] [234abcdy] ->  [3] [6]
# Possible pairs for [1234ccd] [34abcdy]
# Pair: [1234bccd] [234abcdy] ->  [2] [6]
# Pair: [1234accd] [234abcdy] ->  [3] [6]
# Possible pairs for [1234acd] [1234acd]
# Pair: [1234accd] [1234acdd] ->  [3] [4]
# Pair: [1234accd] [1234abcd] ->  [3] [5]
# Pair: [1234acdd] [1234acdd] ->  [4] [4]
# Pair: [1234acdd] [1234abcd] ->  [4] [5]
# Possible pairs for [1234acd] [234abcd]
# Pair: [1234accd] [1234abcd] ->  [3] [5]
# Pair: [1234accd] [234abcdy] ->  [3] [6]
# Pair: [1234acdd] [1234abcd] ->  [4] [5]
# Pair: [1234acdd] [234abcdy] ->  [4] [6]
# Possible pairs for [1234acd] [34abcdy]
# Pair: [1234accd] [234abcdy] ->  [3] [6]
# Pair: [1234acdd] [234abcdy] ->  [4] [6]
# Possible pairs for [1234acd] [234abcd]
# Pair: [1234acdd] [1234abcd] ->  [4] [5]
# Pair: [1234acdd] [234abcdy] ->  [4] [6]
# Pair: [1234abcd] [1234abcd] ->  [5] [5]
# Pair: [1234abcd] [234abcdy] ->  [5] [6]
# Possible pairs for [1234acd] [34abcdy]
# Pair: [1234acdd] [234abcdy] ->  [4] [6]
# Pair: [1234abcd] [234abcdy] ->  [5] [6]
# Possible pairs for [234abcd] [34abcdy]
# Pair: [1234abcd] [234abcdy] ->  [5] [6]
# Pair: [234abcdy] [234abcdy] ->  [6] [6]
# -------------- In len(list_dict) <= 7 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'123abcdx': {0}, '1234abcd': {1, 5}, '1234bccd': {2}, '1234accd': {3}, '1234acdd': {4}, '234abcdy': {6}})
# No previous dict for i = [8] | cur_len = [8]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'123abcdx': {0}, '1234abcd': {1, 5}, '1234bccd': {2}, '1234accd': {3}, '1234acdd': {4}, '234abcdy': {6}})
# Possible pairs for [123abcdx] [1234abcd]
# Pair: [1234abcdx] [1234abcdx] ->  [0] [0]
# Pair: [1234abcdx] [1234abccd] ->  [0] [1]
# Possible pairs for [123abcdx] [1234bccd]
# Pair: [1234abcdx] [1234abccd] ->  [0] [1]
# Pair: [1234abcdx] [1234abccd] ->  [0] [2]
# Possible pairs for [123abcdx] [1234accd]
# Pair: [1234abcdx] [1234abccd] ->  [0] [2]
# Pair: [1234abcdx] [1234accdd] ->  [0] [3]
# Possible pairs for [123abcdx] [1234acdd]
# Pair: [1234abcdx] [1234accdd] ->  [0] [3]
# Pair: [1234abcdx] [1234abcdd] ->  [0] [4]
# Possible pairs for [123abcdx] [1234abcd]
# Pair: [1234abcdx] [1234abcdd] ->  [0] [4]
# Pair: [1234abcdx] [1234abcdy] ->  [0] [5]
# Possible pairs for [123abcdx] [234abcdy]
# Pair: [1234abcdx] [1234abcdy] ->  [0] [5]
# Possible pairs for [1234abcd] [1234bccd]
# Pair: [1234abcdx] [1234abccd] ->  [0] [1]
# Pair: [1234abcdx] [1234abccd] ->  [0] [2]
# Pair: [1234abccd] [1234abccd] ->  [1] [1]
# Pair: [1234abccd] [1234abccd] ->  [1] [2]
# Possible pairs for [1234abcd] [1234accd]
# Pair: [1234abcdx] [1234abccd] ->  [0] [2]
# Pair: [1234abcdx] [1234accdd] ->  [0] [3]
# Pair: [1234abccd] [1234abccd] ->  [1] [2]
# Pair: [1234abccd] [1234accdd] ->  [1] [3]
# Possible pairs for [1234abcd] [1234acdd]
# Pair: [1234abcdx] [1234accdd] ->  [0] [3]
# Pair: [1234abcdx] [1234abcdd] ->  [0] [4]
# Pair: [1234abccd] [1234accdd] ->  [1] [3]
# Pair: [1234abccd] [1234abcdd] ->  [1] [4]
# Possible pairs for [1234abcd] [1234abcd]
# Pair: [1234abcdx] [1234abcdd] ->  [0] [4]
# Pair: [1234abcdx] [1234abcdy] ->  [0] [5]
# Pair: [1234abccd] [1234abcdd] ->  [1] [4]
# Pair: [1234abccd] [1234abcdy] ->  [1] [5]
# Possible pairs for [1234abcd] [234abcdy]
# Pair: [1234abcdx] [1234abcdy] ->  [0] [5]
# Pair: [1234abccd] [1234abcdy] ->  [1] [5]
# Possible pairs for [1234bccd] [1234accd]
# Pair: [1234abccd] [1234abccd] ->  [1] [2]
# Pair: [1234abccd] [1234accdd] ->  [1] [3]
# Pair: [1234abccd] [1234abccd] ->  [2] [2]
# Pair: [1234abccd] [1234accdd] ->  [2] [3]
# Possible pairs for [1234bccd] [1234acdd]
# Pair: [1234abccd] [1234accdd] ->  [1] [3]
# Pair: [1234abccd] [1234abcdd] ->  [1] [4]
# Pair: [1234abccd] [1234accdd] ->  [2] [3]
# Pair: [1234abccd] [1234abcdd] ->  [2] [4]
# Possible pairs for [1234bccd] [1234abcd]
# Pair: [1234abccd] [1234abcdd] ->  [1] [4]
# Pair: [1234abccd] [1234abcdy] ->  [1] [5]
# Pair: [1234abccd] [1234abcdd] ->  [2] [4]
# Pair: [1234abccd] [1234abcdy] ->  [2] [5]
# Possible pairs for [1234bccd] [234abcdy]
# Pair: [1234abccd] [1234abcdy] ->  [1] [5]
# Pair: [1234abccd] [1234abcdy] ->  [2] [5]
# Possible pairs for [1234accd] [1234acdd]
# Pair: [1234abccd] [1234accdd] ->  [2] [3]
# Pair: [1234abccd] [1234abcdd] ->  [2] [4]
# Pair: [1234accdd] [1234accdd] ->  [3] [3]
# Pair: [1234accdd] [1234abcdd] ->  [3] [4]
# Possible pairs for [1234accd] [1234abcd]
# Pair: [1234abccd] [1234abcdd] ->  [2] [4]
# Pair: [1234abccd] [1234abcdy] ->  [2] [5]
# Pair: [1234accdd] [1234abcdd] ->  [3] [4]
# Pair: [1234accdd] [1234abcdy] ->  [3] [5]
# Possible pairs for [1234accd] [234abcdy]
# Pair: [1234abccd] [1234abcdy] ->  [2] [5]
# Pair: [1234accdd] [1234abcdy] ->  [3] [5]
# Possible pairs for [1234acdd] [1234abcd]
# Pair: [1234accdd] [1234abcdd] ->  [3] [4]
# Pair: [1234accdd] [1234abcdy] ->  [3] [5]
# Pair: [1234abcdd] [1234abcdd] ->  [4] [4]
# Pair: [1234abcdd] [1234abcdy] ->  [4] [5]
# Possible pairs for [1234acdd] [234abcdy]
# Pair: [1234accdd] [1234abcdy] ->  [3] [5]
# Pair: [1234abcdd] [1234abcdy] ->  [4] [5]
# Possible pairs for [1234abcd] [234abcdy]
# Pair: [1234abcdd] [1234abcdy] ->  [4] [5]
# Pair: [1234abcdy] [1234abcdy] ->  [5] [5]
# -------------- In len(list_dict) <= 8 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'1234abcdx': {0}, '1234abccd': {1, 2}, '1234accdd': {3}, '1234abcdd': {4}, '1234abcdy': {5}})
# No previous dict for i = [9] | cur_len = [9]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'1234abcdx': {0}, '1234abccd': {1, 2}, '1234accdd': {3}, '1234abcdd': {4}, '1234abcdy': {5}})
# Possible pairs for [1234abcdx] [1234abccd]
# Pair: [1234abccdx] [1234abccdx] ->  [0] [0]
# Pair: [1234abccdx] [1234aabccd] ->  [0] [1]
# Possible pairs for [1234abcdx] [1234abccd]
# Pair: [1234abccdx] [1234aabccd] ->  [0] [1]
# Pair: [1234abccdx] [1234abccdd] ->  [0] [2]
# Possible pairs for [1234abcdx] [1234accdd]
# Pair: [1234abccdx] [1234abccdd] ->  [0] [2]
# Pair: [1234abccdx] [1234abccdd] ->  [0] [3]
# Possible pairs for [1234abcdx] [1234abcdd]
# Pair: [1234abccdx] [1234abccdd] ->  [0] [3]
# Pair: [1234abccdx] [1234abcddy] ->  [0] [4]
# Possible pairs for [1234abcdx] [1234abcdy]
# Pair: [1234abccdx] [1234abcddy] ->  [0] [4]
# Possible pairs for [1234abccd] [1234abccd]
# Pair: [1234abccdx] [1234aabccd] ->  [0] [1]
# Pair: [1234abccdx] [1234abccdd] ->  [0] [2]
# Pair: [1234aabccd] [1234aabccd] ->  [1] [1]
# Pair: [1234aabccd] [1234abccdd] ->  [1] [2]
# Possible pairs for [1234abccd] [1234accdd]
# Pair: [1234abccdx] [1234abccdd] ->  [0] [2]
# Pair: [1234abccdx] [1234abccdd] ->  [0] [3]
# Pair: [1234aabccd] [1234abccdd] ->  [1] [2]
# Pair: [1234aabccd] [1234abccdd] ->  [1] [3]
# Possible pairs for [1234abccd] [1234abcdd]
# Pair: [1234abccdx] [1234abccdd] ->  [0] [3]
# Pair: [1234abccdx] [1234abcddy] ->  [0] [4]
# Pair: [1234aabccd] [1234abccdd] ->  [1] [3]
# Pair: [1234aabccd] [1234abcddy] ->  [1] [4]
# Possible pairs for [1234abccd] [1234abcdy]
# Pair: [1234abccdx] [1234abcddy] ->  [0] [4]
# Pair: [1234aabccd] [1234abcddy] ->  [1] [4]
# Possible pairs for [1234abccd] [1234accdd]
# Pair: [1234aabccd] [1234abccdd] ->  [1] [2]
# Pair: [1234aabccd] [1234abccdd] ->  [1] [3]
# Pair: [1234abccdd] [1234abccdd] ->  [2] [2]
# Pair: [1234abccdd] [1234abccdd] ->  [2] [3]
# Possible pairs for [1234abccd] [1234abcdd]
# Pair: [1234aabccd] [1234abccdd] ->  [1] [3]
# Pair: [1234aabccd] [1234abcddy] ->  [1] [4]
# Pair: [1234abccdd] [1234abccdd] ->  [2] [3]
# Pair: [1234abccdd] [1234abcddy] ->  [2] [4]
# Possible pairs for [1234abccd] [1234abcdy]
# Pair: [1234aabccd] [1234abcddy] ->  [1] [4]
# Pair: [1234abccdd] [1234abcddy] ->  [2] [4]
# Possible pairs for [1234accdd] [1234abcdd]
# Pair: [1234abccdd] [1234abccdd] ->  [2] [3]
# Pair: [1234abccdd] [1234abcddy] ->  [2] [4]
# Pair: [1234abccdd] [1234abccdd] ->  [3] [3]
# Pair: [1234abccdd] [1234abcddy] ->  [3] [4]
# Possible pairs for [1234accdd] [1234abcdy]
# Pair: [1234abccdd] [1234abcddy] ->  [2] [4]
# Pair: [1234abccdd] [1234abcddy] ->  [3] [4]
# Possible pairs for [1234abcdd] [1234abcdy]
# Pair: [1234abccdd] [1234abcddy] ->  [3] [4]
# Pair: [1234abcddy] [1234abcddy] ->  [4] [4]
# -------------- In len(list_dict) <= 9 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'1234abccdx': {0}, '1234aabccd': {1}, '1234abccdd': {2, 3}, '1234abcddy': {4}})
# No previous dict for i = [10] | cur_len = [10]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'1234abccdx': {0}, '1234aabccd': {1}, '1234abccdd': {2, 3}, '1234abcddy': {4}})
# Possible pairs for [1234abccdx] [1234aabccd]
# Pair: [1234aabccdx] [1234aabccdx] ->  [0] [0]
# Pair: [1234aabccdx] [1234aabccdd] ->  [0] [1]
# Possible pairs for [1234abccdx] [1234abccdd]
# Pair: [1234aabccdx] [1234aabccdd] ->  [0] [1]
# Pair: [1234aabccdx] [1234abbccdd] ->  [0] [2]
# Possible pairs for [1234abccdx] [1234abccdd]
# Pair: [1234aabccdx] [1234abbccdd] ->  [0] [2]
# Pair: [1234aabccdx] [1234abccddy] ->  [0] [3]
# Possible pairs for [1234abccdx] [1234abcddy]
# Pair: [1234aabccdx] [1234abccddy] ->  [0] [3]
# Possible pairs for [1234aabccd] [1234abccdd]
# Pair: [1234aabccdx] [1234aabccdd] ->  [0] [1]
# Pair: [1234aabccdx] [1234abbccdd] ->  [0] [2]
# Pair: [1234aabccdd] [1234aabccdd] ->  [1] [1]
# Pair: [1234aabccdd] [1234abbccdd] ->  [1] [2]
# Possible pairs for [1234aabccd] [1234abccdd]
# Pair: [1234aabccdx] [1234abbccdd] ->  [0] [2]
# Pair: [1234aabccdx] [1234abccddy] ->  [0] [3]
# Pair: [1234aabccdd] [1234abbccdd] ->  [1] [2]
# Pair: [1234aabccdd] [1234abccddy] ->  [1] [3]
# Possible pairs for [1234aabccd] [1234abcddy]
# Pair: [1234aabccdx] [1234abccddy] ->  [0] [3]
# Pair: [1234aabccdd] [1234abccddy] ->  [1] [3]
# Possible pairs for [1234abccdd] [1234abccdd]
# Pair: [1234aabccdd] [1234abbccdd] ->  [1] [2]
# Pair: [1234aabccdd] [1234abccddy] ->  [1] [3]
# Pair: [1234abbccdd] [1234abbccdd] ->  [2] [2]
# Pair: [1234abbccdd] [1234abccddy] ->  [2] [3]
# Possible pairs for [1234abccdd] [1234abcddy]
# Pair: [1234aabccdd] [1234abccddy] ->  [1] [3]
# Pair: [1234abbccdd] [1234abccddy] ->  [2] [3]
# Possible pairs for [1234abccdd] [1234abcddy]
# Pair: [1234abbccdd] [1234abccddy] ->  [2] [3]
# Pair: [1234abccddy] [1234abccddy] ->  [3] [3]
# -------------- In len(list_dict) <= 10 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'1234aabccdx': {0}, '1234aabccdd': {1}, '1234abbccdd': {2}, '1234abccddy': {3}})
# No previous dict for i = [11] | cur_len = [11]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'1234aabccdx': {0}, '1234aabccdd': {1}, '1234abbccdd': {2}, '1234abccddy': {3}})
# Possible pairs for [1234aabccdx] [1234aabccdd]
# Pair: [1234aabccddx] [1234aabccddx] ->  [0] [0]
# Pair: [1234aabccddx] [1234aabbccdd] ->  [0] [1]
# Possible pairs for [1234aabccdx] [1234abbccdd]
# Pair: [1234aabccddx] [1234aabbccdd] ->  [0] [1]
# Pair: [1234aabccddx] [1234abbccddy] ->  [0] [2]
# Possible pairs for [1234aabccdx] [1234abccddy]
# Pair: [1234aabccddx] [1234abbccddy] ->  [0] [2]
# Possible pairs for [1234aabccdd] [1234abbccdd]
# Pair: [1234aabccddx] [1234aabbccdd] ->  [0] [1]
# Pair: [1234aabccddx] [1234abbccddy] ->  [0] [2]
# Pair: [1234aabbccdd] [1234aabbccdd] ->  [1] [1]
# Pair: [1234aabbccdd] [1234abbccddy] ->  [1] [2]
# Possible pairs for [1234aabccdd] [1234abccddy]
# Pair: [1234aabccddx] [1234abbccddy] ->  [0] [2]
# Pair: [1234aabbccdd] [1234abbccddy] ->  [1] [2]
# Possible pairs for [1234abbccdd] [1234abccddy]
# Pair: [1234aabbccdd] [1234abbccddy] ->  [1] [2]
# Pair: [1234abbccddy] [1234abbccddy] ->  [2] [2]
# -------------- In len(list_dict) <= 11 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'1234aabccddx': {0}, '1234aabbccdd': {1}, '1234abbccddy': {2}})
# No previous dict for i = [12] | cur_len = [12]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'1234aabccddx': {0}, '1234aabbccdd': {1}, '1234abbccddy': {2}})
# Possible pairs for [1234aabccddx] [1234aabbccdd]
# Pair: [1234aabbccddx] [1234aabbccddx] ->  [0] [0]
# Pair: [1234aabbccddx] [1234aabbccddy] ->  [0] [1]
# Possible pairs for [1234aabccddx] [1234abbccddy]
# Pair: [1234aabbccddx] [1234aabbccddy] ->  [0] [1]
# Possible pairs for [1234aabbccdd] [1234abbccddy]
# Pair: [1234aabbccddx] [1234aabbccddy] ->  [0] [1]
# Pair: [1234aabbccddy] [1234aabbccddy] ->  [1] [1]
# -------------- In len(list_dict) <= 12 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'1234aabbccddx': {0}, '1234aabbccddy': {1}})
# No previous dict for i = [13] | cur_len = [13]
# Before Inner Loop
#  --- next_dict_possible ---
# defaultdict(<class 'set'>, {})
#  --- cur_dict ---
# defaultdict(<class 'set'>, {'1234aabbccddx': {0}, '1234aabbccddy': {1}})
# Possible pairs for [1234aabbccddx] [1234aabbccddy]
# Pair: [1234aabbccddxy] [1234aabbccddxy] ->  [0] [0]
# -------------- In len(list_dict) <= 13 ----------------
# After Inner Loop
# defaultdict(<class 'set'>, {'1234aabbccddxy': {0}})
# Answer = [10]
# 10

# %% [markdown]
# ### Finish

# %%
dict_all
# Out:
# defaultdict(set,
#             {'x': {0},
#              'a': {1, 10},
#              'b': {2, 12},
#              'c': {3, 9},
#              'd': {4, 11},
#              '1': {5},
#              '2': {6},
#              '3': {7},
#              '4': {8},
#              'y': {13},
#              '1234abccd': {1, 2},
#              '1234abccdd': {2, 3},
#              '1234cd': {3, 4},
#              '1234acd': {4, 5}})

# %%
comb(3,2)
# Out:
# 3

# %%
sherlockAndAnagrams('54a123a54')
# Out:
# --------- In substring length = 1
# defaultdict(<class 'set'>, {'5': {0, 7}, '4': {8, 1}, 'a': {2, 6}, '1': {3}, '2': {4}, '3': {5}})
# Length of cur_dict i=[0] | [6]
# --------- In substring length = 2
# {'45': {0, 7}}
# Length of cur_dict i=[1] | [1]
# --------- In substring length = 3
# {'45a': {0, 6}}
# Length of cur_dict i=[2] | [1]
# ------ Initial dict_all ------
# defaultdict(<class 'set'>, {'5': {0, 7}, '4': {8, 1}, 'a': {2, 6}, '1': {3}, '2': {4}, '3': {5}, '45': {0, 7}, '45a': {0, 6}})
# ------ Updated dict_all ------
# defaultdict(<class 'set'>, {'5': {0, 7}, '4': {8, 1}, 'a': {2, 6}, '1': {3}, '2': {4}, '3': {5}, '45': {0, 7}, '45a': {0, 6}, '12345aa': {0, 1, 2}, '123a': {2, 3}, '12345a': {0, 3}})
# Answer = [10]
# 10

# %%
for i,v in enumerate(s):
    print(i,v)
# Out:
# 0 a
# 1 b
# 2 c
# 3 d

# %%
dict_all
# Out:
# {'a': set(),
#  'b': set(),
#  'c': set(),
#  'd': set(),
#  'e': set(),
#  'f': set(),
#  'g': set(),
#  'h': set(),
#  'i': set(),
#  'j': set(),
#  'k': {0, 1, 2, 3},
#  'l': set(),
#  'm': set(),
#  'n': set(),
#  'o': set(),
#  'p': set(),
#  'q': set(),
#  'r': set(),
#  's': set(),
#  't': set(),
#  'u': set(),
#  'v': set(),
#  'w': set(),
#  'x': set(),
#  'y': set(),
#  'z': set(),
#  'kk': {0, 1, 2},
#  'kkk': {0, 1}}

# %%
name_test = 'input00.txt'

f_input = open(f"./in/{name_test}", "r")

if __name__ == '__main__':
#     fptr = open(os.environ['OUTPUT_PATH'], 'w')
    
    q = int(f_input.readline().strip())

    for q_itr in range(q):
        s = f_input.readline().strip('\n')

        result = sherlockAndAnagrams(s)
        
#         fptr.write(str(result) + '\n')

#     fptr.close()
# Out:
# --------- In substring length = 1
# defaultdict(<class 'set'>, {'a': {0, 3}, 'b': {1, 2}})
# Length of cur_dict i=[0] | [2]
# --------- In substring length = 2
# {'ab': {0, 2}}
# Length of cur_dict i=[1] | [1]
# --------- In substring length = 3
# {'abb': {0, 1}}
# Length of cur_dict i=[2] | [1]
# ------ Initial dict_all ------
# defaultdict(<class 'set'>, {'a': {0, 3}, 'b': {1, 2}, 'ab': {0, 2}, 'abb': {0, 1}})
# ------ Updated dict_all ------
# defaultdict(<class 'set'>, {'a': {0, 3}, 'b': {1, 2}, 'ab': {0, 2}, 'abb': {0, 1}})
# Answer = [4]
# --------- In substring length = 1
# defaultdict(<class 'set'>, {'a': {0}, 'b': {1}, 'c': {2}, 'd': {3}})
# Length of cur_dict i=[0] | [4]
# ------ Initial dict_all ------
# defaultdict(<class 'set'>, {'a': {0}, 'b': {1}, 'c': {2}, 'd': {3}})
# ------ Updated dict_all ------
# defaultdict(<class 'set'>, {'a': {0}, 'b': {1}, 'c': {2}, 'd': {3}})
# Answer = [0]

# %%
list_dict[0]
# Out:
# {'a': {0},
#  'b': {1},
#  'c': {2},
#  'd': {3},
#  'e': set(),
#  'f': set(),
#  'g': set(),
#  'h': set(),
#  'i': set(),
#  'j': set(),
#  'k': set(),
#  'l': set(),
#  'm': set(),
#  'n': set(),
#  'o': set(),
#  'p': set(),
#  'q': set(),
#  'r': set(),
#  's': set(),
#  't': set(),
#  'u': set(),
#  'v': set(),
#  'w': set(),
#  'x': set(),
#  'y': set(),
#  'z': set()}

# %%
"".join(sorted(s[0:6]))
# Out:
# 'aabb'

# %%
list_dict
# Out:
# [{'a': {0},
#   'b': {1},
#   'c': {2},
#   'd': {3},
#   'e': set(),
#   'f': set(),
#   'g': set(),
#   'h': set(),
#   'i': set(),
#   'j': set(),
#   'k': set(),
#   'l': set(),
#   'm': set(),
#   'n': set(),
#   'o': set(),
#   'p': set(),
#   'q': set(),
#   'r': set(),
#   's': set(),
#   't': set(),
#   'u': set(),
#   'v': set(),
#   'w': set(),
#   'x': set(),
#   'y': set(),
#   'z': set()}]

# %% [markdown]
# # Old

# %%
def sherlockAndAnagrams_old(s):
    global list_dict
    global dict_all
    global list_dict_possible
    
    total = 0
    
    list_dict = []
    dict_1 = defaultdict(set)
    
    list_dict.append(dict_1)

    for i, char in enumerate(s):
        dict_1[char].add(i)
            
    dict_1 = {k:v for k,v in dict_1.items() if len(v) >= 1}
    
    i_d = 0

#     print(dict_1)
#     print(list_dict[i_d])
    
    while len(list_dict[i_d]) > 0:
#         print(f'--------- In substring length = {i_d+1}')
#         print(list_dict[i_d])
        
#         print(f'Length of cur_dict i=[{i_d}] | [{len(list_dict[i_d])}] ')
        cur_dict = list_dict[i_d]
        
        next_dict = defaultdict(set)
        i_d += 1
        
        for k,v in cur_dict.items():
            
            for i in v:
                if i-1 >= 0:
                    next_dict["".join(sorted(s[i-1:i+i_d]))].add(i-1)
                    
                if i_d + i < len(s):
                    next_dict["".join(sorted(s[i:i+i_d+1]))].add(i)
                    
        next_dict = {k:v for k,v in next_dict.items() if len(v) >= 2}
        
        if next_dict:
            list_dict.append(next_dict)

        else:
#             print(next_dict)
            break

    
#     print('------ Initial dict_all ------')  
#     print(dict_all)
    
    
    dict_all = defaultdict(set)
    dict_all.update({key:val for d in list_dict for key,val in d.items()})
    
        
    for k in list(dict_all):
        v_pairs = combinations(dict_all[k], 2)
        for pair in v_pairs:
            
            pair = sorted(pair)
            
            len_k = len(k)
            
            dict_all["".join(sorted(s[pair[0]:pair[1]]))].add(pair[0])
            dict_all["".join(sorted(s[pair[0]+len_k:pair[1]+len_k]))].add(pair[0]+len_k)
   
    for set_s in dict_all.values():
        total += comb(len(set_s), 2)
    
    print(f'Answer = [{total}]')
    
    return total

# %% [markdown]
# # Backup

# %%
def sherlockAndAnagrams(s):
    global list_dict
    global dict_all
    global list_dict_possible
    
    total = 0
    
    list_dict = []
    dict_1 = defaultdict(set)
    
    list_dict.append(dict_1)

    for i, char in enumerate(s):
        dict_1[char].add(i)
            
    dict_1 = {k:v for k,v in dict_1.items() if len(v) >= 1}
    
    i_d = 0

#     print(dict_1)
#     print(list_dict[i_d])
    
    while len(list_dict[i_d]) > 0:
#         print(f'--------- In substring length = {i_d+1}')
#         print(list_dict[i_d])
        
#         print(f'Length of cur_dict i=[{i_d}] | [{len(list_dict[i_d])}] ')
        cur_dict = list_dict[i_d]
        
        next_dict = defaultdict(set)
        i_d += 1
        
        for k,v in cur_dict.items():
            
            for i in v:
                if i-1 >= 0:
                    next_dict["".join(sorted(s[i-1:i+i_d]))].add(i-1)
                    
                if i_d + i < len(s):
                    next_dict["".join(sorted(s[i:i+i_d+1]))].add(i)
                    
        next_dict = {k:v for k,v in next_dict.items() if len(v) >= 2}
        
        if next_dict:
            list_dict.append(next_dict)

        else:
#             print(next_dict)
            break

    
#     print('------ Initial dict_all ------')  
#     print(dict_all)
    
    
# ------------------ Part 3


    list_dict_possible = deepcopy(list_dict)
    
    all_i = set.union(*dict_1.values())
    
    for i in range(1,len(s)):
        
        next_dict_possible = defaultdict(set)
        
        if len(list_dict_possible) > i:
            next_dict_possible.update(list_dict_possible[i])
            
        else:
            print(f'No previous dict for i = [{i}] | cur_len = [{len(list_dict_possible)}]')
        
        cur_dict = list_dict_possible[i-1]
        
        print('Before Inner Loop')
        
        print(' --- next_dict_possible ---')
        print(next_dict_possible)
        print(' --- cur_dict ---')
        print(cur_dict)
        
        
        for k, v in cur_dict.items():
            pairs = combinations(v, 2)
            
            for pair in pairs:
                
                pair = sorted(pair)
                len_k = len(k)
                
                possible_pairs = get_adjacent(pair[0],pair[1],len_k,all_i)
                
                
                cur_str_l = "".join(sorted(s[pair[0]:pair[0]+len_k]))
                cur_str_r = "".join(sorted(s[pair[1]:pair[1]+len_k]))                 
                        
                print(f'Possible pairs for [{cur_str_l}] [{cur_str_r}]')
                
                for pos_pair in possible_pairs:
                    l_pos, r_pos = pos_pair
                    l_sub = "".join(sorted(s[l_pos:l_pos+len_k+1]))
                    r_sub = "".join(sorted(s[r_pos:r_pos+len_k+1]))
                                    
                    next_dict_possible[l_sub].add(l_pos)
                    next_dict_possible[r_sub].add(r_pos)
                      
                    print(f'Pair: [{l_sub}] [{r_sub}] ->  [{l_pos}] [{r_pos}] ')
                    
                
             
        next_dict = {k:v for k,v in next_dict_possible.items() if len(v) >= 2}
        
        if len(list_dict) > i:
            list_dict_possible[i].update(next_dict_possible)
            list_dict[i] = next_dict
            
            print(f'-------------- In len(list_dict) > {i} ---------------- ')
        
        else:
            print(f'-------------- In len(list_dict) <= {i} ---------------- ')
            
            list_dict_possible.append(next_dict_possible)
            list_dict.append(next_dict)
            
        print('After Inner Loop')
        print(next_dict_possible)
    
    
    # Check for equality -> Insert to dict_all
    
    dict_all = defaultdict(set)
    dict_all.update({key:val for d in list_dict for key,val in d.items()})
    
        
    for k in list(dict_all):
        v_pairs = combinations(dict_all[k], 2)
        for pair in v_pairs:
            
            pair = sorted(pair)
            
            len_k = len(k)
            
            dict_all["".join(sorted(s[pair[0]:pair[1]]))].add(pair[0])
            dict_all["".join(sorted(s[pair[0]+len_k:pair[1]+len_k]))].add(pair[0]+len_k)
   
    for set_s in dict_all.values():
        total += comb(len(set_s), 2)
    
    print(f'Answer = [{total}]')
    
    return total
